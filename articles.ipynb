# %%
import sys
if ("./virt/lib/python3.7/site-packages" not in sys.path):
    sys.path.append("./virt/lib/python3.7/site-packages")
if ("/Users/dylanc_home/Library/Python/2.7/lib/python/site-packages" not in sys.path):
    sys.path.append("/Users/dylanc_home/Library/Python/2.7/lib/python/site-packages")
if ("/usr/local/lib/python2.7/site-packages" not in sys.path):
    sys.path.append("/usr/local/lib/python2.7/site-packages")
# since sys.path list didn't contain the site-packages from the virtual environment, then jupyter didn't know
# where to find pdfminer or PyPDF2
import dask.dataframe as dd
import os
import warnings

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import numpy as np
import arff
import codecs
import csv

# %%
from gensim.models import Word2Vec,Phrases
from gensim.test.utils import get_tmpfile, common_texts

# %%
data_lack_of_real_world_data3gram = pd.Series([0.99993,0.9987,0.859,0.783, -0.437],
                               index=["Cloud Computing Applications",
                                      "Cloud-based Services",
                                      "Remote Cloud Edge",
                                      "Cloud Computer",
                                      "Cloud Edge Computing"])

# %%
fig, ax = plt.subplots(figsize=(20,20))
pal = sns.color_palette("Blues_d", len(data_lack_of_real_world_data3gram))
rank = data_lack_of_real_world_data3gram.argsort().argsort()
sdatabig3 = sns.barplot(x=data_lack_of_real_world_data3gram.index, y=data_lack_of_real_world_data3gram, palette=np.array(pal[::-1])[rank])
plt.xticks(rotation=80)
sdatabig3.set_title("Phrase Distances from 'Big Data'",weight='bold').set_fontsize(35)
sdatabig3.set_ylabel("Distance",weight="bold").set_fontsize(35)
sdatabig3.set_xlabel("Phrase",weight='bold').set_fontsize(35)
plt.rc("xtick",labelsize=40)
plt.rc("ytick",labelsize=40)
sdatabig3.figure.savefig("lackofdata3gram.png")

# %%
import PyPDF2

# %%
from sklearn.decomposition import PCA

# %%
import tika 
from tika import parser
from bs4 import BeautifulSoup
tika.initVM()
from graphviz import Digraph, nohtml

import psutil

from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
import io
import time

# %%
from sklearn.manifold import TSNE

# %%
from gensim.similarities import WmdSimilarity

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/dylanc_home/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/dylanc_home/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.util import ngrams

# %%
import re

# %%
s = set(stopwords.words())

# %%
import os
len(os.listdir("../literature/Taxonomy/Collected"))
# Out:
# 157

# %%
categories = \
{"Lack of Real-World Network Data":{"Simulated Realism":["Intrusion Detection System Using Honeypots and Swarm Intelligence",
                                                 "Researches on the IPv6 Network Safeguard Linked System",
                                                 "An Intrusion Detection System Based on Honeypot Technology",
                                                 "Generating realistic intrusion detection system dataset based on fuzzy qualitative modeling",
                                                 "UNSW-NB15- A Comprehensive Data set for Network Intrusion Detection systems",
                                                         "Hypervisor-based cloud intrusion detection through online multivariate statistical change tracking",
                                                    "Real time dataset generation framework for intrusion detection systems in IoT",
                                                     "Detecting Return-to-libc Buffer Overflow Attacks Using Network Intrusion Detection Systems",
                                                     "A Credible Network Intrusion Detection System Based on Grid",
                                                     "Virtual Machine Monitor-Based Lightweight Intrusion Detection",
                                                     "NICE- Network Intrusion Detection and Countermeasure Selection in Virtual Network Systems",
                                                     "vNIDS- Towards Elastic Security with Safe and Efficient Virtualization of Network Intrusion Detection Systems"],
                                    "Collection in Real Network Infrastructure":
                                    ["LITNET-2020- An Annotated Real-World Network Flow Dataset for Network Intrusion Detection",
                                     "UGR'16- A New Dataset for the Evaluation of Cyclostationarity-Based Network IDSs",
                                     "Clustering of Snort Alerts to Identify Patterns and Reduce Analyst Workload"]},
"Noisy Data":{"Feature Normalization":['A New Method of Fuzzy Support Vector Machine Algorithm for Intrusion Detection',
                                       "Toward an Online Network Intrusion Detection System Based on Ensemble Learning",
                                       "PCA filtering and probabilistic SOM for network intrusion detection"],
             "Density-Based Feature Selection":["Semi-Supervised K-Means DDoS Detection Method Using Hybrid Feature Selection Algorithm",
                                                "A Novel Semi-Supervised Learning Approach for Network Intrusion Detection on Cloud-Based Robotic System",
                                                "A local density-based approach for outlier detection"]},
"Redundant Data": {"Redundancy Removal Frameworks":["Towards a Reliable Comparison and Evaluation of Network Intrusion Detection Systems Based on Machine Learning Approaches",
                                                   "Evaluating Deep Learning Based Network Intrusion Detection System in Adversarial Environment"],
                  "Feature Selection":["Selection of Effective Features for BGP Anomaly Detection",
                                       "A novel feature-selection approach based on the cuttlefish optimization algorithm for intrusion detection systems",
                                       "The Detection of Network Intrusion Based on Improved Adaboost Algorithm",
                                       "Dimensionality reduction with IG-PCA and ensemble classifier for network intrusion detection",
                                       "A GA-LR wrapper approach for feature selection in network intrusion detection",
                                       "Dimensionality reduction using Principal Component Analysis for network intrusion detection",
                                       "Effects-based feature identification for network intrusion detection",
                                       "The significant features of the UNSW-NB15 and the KDD99 data sets for Network Intrusion Detection Systems",
                                       "A novel architecture combined with optimal parameters for back propagation neural networks applied to anomaly network intrusion detection",
                                       "A novel intrusion detection system based on hierarchical clustering and support vector machines",
                                       "Network intrusion detection system based on recursive feature addition and bigram technique",
                                       "Wireless Network Intrusion Detection Based on Improved Convolutional Neural Network",
                                       "Evolving deep learning architectures for network intrusion detection using a double PSO metaheuristic",
                                       "Network Intrusion Detection Based on PSO-Xgboost Model"],
                  "Data Discretization":["A Discretized Extended Feature Space (DEFS) Model to Improve the Anomaly Detection Performance in Network Intrusion Detection Systems",
                                         "A network intrusion detection system based on a Hidden Naive Bayes multiclass classifier",
                                         "Feature Selection Based on Rough Set and Modified Genetic Algorithm for Intrusion Detection",
                                         "A Naive Feature Selection Method and Its Application in Network Intrusion Detection",
                                         "Machine-Learning-Based Feature Selection Techniques for Large-Scale Network Intrusion Detection",
                                         "Intrusion Detection using Naive Bayes Classifier with Feature Reduction",
                                         "Cyber intrusion detection by combined feature selection algorithm"],
                  "Rough Set":["An efficient feature selection based Bayesian and Rough set approach for intrusion detection",
                              "Adaptive intrusion detection via GA-GOGMM-based pattern learning with fuzzy rough set-based attribute selection",
                               "Intelligent temporal classification and fuzzy rough set-based feature selection algorithm for intrusion detection system in WSNs",
                               "Development of Rough Set- Hypergraph Technique for Key Feature Identification in Intrusion Detection Systems",
                               "A hybrid network intrusion detection system using simplified swarm optimization (SSO)"],
                  "Autoencoder":["HELAD- A novel network anomaly detection model based on heterogeneous ensemble learning",
                                 "Deep Learning Approach Combining Sparse Autoencoder With SVM for Network Intrusion Detection"],
                  "Attention Mechanism":["BAT- Deep Learning Methods on Network Intrusion Detection Using NSL-KDD Dataset"],
                  "Hypergraph Helly and Trim Properties To Identify Informative Features":["Detection of Cyberattacks in Industrial Control systems using Enhanced Principal Component Analysis and Hypergraph based Convolution Neural Network (EPCA-HG-CNN)"]
                  },
"Weakly Correlated Data":{"Increase Dimensionality":["Robust detection for network intrusion of industrial IoT based on multi-CNN fusion"]},
"Too Few Labeled Data":{"Semi-supervised learning":["Semi-Supervised Learning based Security to Detect and Mitigate Intrusions in IoT Network",
                                                    "Intrusion Detection Algorithm Based On Semi-supervised Learning",
                                                    "Nonparametric Semi-Supervised Learning for Network Intrusion Detection- Combining Performance Improvements with Realistic In-Situ Training",
                                                    "Research on Intrusion Detection method based on SVM Co-training",
                                                    "Unsupervised Network Intrusion Detection Systems- Detecting the Unknown without Knowledge",
                                                    "A Novel Two-Stage Deep Learning Model for Efficient Network Intrusion Detection",
                                                    "Improved competitive learning neural networks for network intrusion and fraud detection"],
                       "Transfer Learning":["Network Anomaly Detection inside Consumer Networks- A Hybrid Approach",
                                            "Overcoming the Lack of Labeled Data- Training Intrusion Detection Models using Transfer Learning"],
                       "Adversarial Sample Generation":["Investigating Adversarial Attacks against Network Intrusion Detection Systems in SDNs",
                                                       "Defending network intrusion detection systems against adversarial evasion attacks",
                                                        "Flow-based network traffic generation using Generative Adversarial Networks",
                                                        "Generative Adversarial Networks For Launching and Thwarting Adversarial Attacks on Network Intrusion Detection Systems",
                                                        "Evading botnet detectors based on flows and Random Forest with adversarial samples",
                                                        "PAC-GAN- Packet Generation of Network Traffic using Generative Adversarial Networks",
                                                        "Addressing Adversarial Attacks Against Security Systems Based on Machine Learning"]},
"Imbalanced Data":{"Over Sampling, Under Sampling":["An effective convolutional neural network based on SMOTE and Gaussian mixture model for intrusion detection in imbalanced dataset",
                                                   "Data Processing and Model Selection for Machine Learning-based Network Intrusion Detection",
                                                   "1D CNN based network intrusion detection with normalization on imbalanced data",
                                                   "Hierarchical intrusion detection using machine learning and knowledge model",
                                                   "Network Intrusion Detection Based on Supervised Adversarial Variational Auto-Encoder With Regularization",
                                                   "A Semi-Boosted Nested Model With Sensitivity-Based Weighted Binarization for Multi-Domain Network Intrusion Detection",
                                                   "An Adaptive Ensemble Machine Learning Model for Intrusion Detection",
                                                   "Network Intrusion Detection Combined Hybrid Sampling With Deep Hierarchical Network"],
                  "Optimal Feature Extraction":["Anomaly-Based Network Intrusion Detection Using SVM",
                                                "An integrated Intrusion Detection Model using consistency based feature selection and LPBoost",
                                                "An improved NSGA-III algorithm for feature selection used in intrusion detection"],
                  "Feature Fusion": ["PCCN- Parallel Cross Convolutional Neural Network for Abnormal Network Traffic Flows Detection in Multi-Class Imbalanced Network Traffic Flows"],
                  "Transfer Learning":["CNN-Based Network Intrusion Detection against Denial-of-Service Attacks"],
                  "Siamese Neural Network":["Siam-IDS- Handling class imbalance problem in Intrusion Detection Systems using Siamese Neural Network"],
                  "Genetic Programming":["Malware Detection Using Genetic Programming",
                                        "Genetic Fuzzy System For Intrusion Detection - Analysis of Improving of multiclass classification accuracy using KDDCup-99 imbalance dataset",
                                        "On the combination of genetic fuzzy systems and pairwise learning for improving detection rates on Intrusion Detection Systems",
                                         "Network Intrusion Detection System using Genetic Network Programming with Support Vector Machine"]
                  },
"Big Data":{"Data Reduction":["Network Intrusion Detection using Hybrid Machine Learning",
                                                 "An Authorized Access Attack Detection Method for Realtime Intrusion Detection System",
                                                "A Deep Learning Approach to Network Intrusion Detection",
                                                "Large High Dimensional Data Handing Using Data Reduction",
                                "Anomalous query access detection in RBAC-administered databases with random forest and PCA",
                                "R1SVM- A Randomised Nonlinear Approach to Large-Scale Anomaly Detection",
                                "Improved Salp Swarm Algorithm based on opposition based learning and novel local search algorithm for feature selection",
                                "An Effective Feature Selection Approach for Network Intrusion Detection",
                                "An Efficient Flow Control Approach for SDN-based Network Threat Detection and Migration Using Support Vector Machine",
                                "An efficient network intrusion detection",
                                "Inductive Intrusion Detection in Flow-Based Network Data using One-Class Support Vector Machines",
                                "An Intrusion Detection System Using a Deep Neural Network With Gated Recurrent Units",
                                "Network Intrusion Detection Based on LDA for Payload Feature Selection",
                                "Sampling Techniques to Accelerate Pattern Matching in Network Intrusion Detection Systems"],
            "Optimized Initial Parameters": ["A Cooperative and Hybrid Network Intrusion Detection Framework in Cloud Computing Based on Snort and Optimized Back Propagation Neural Network"],
            "Edge Computing": ["RoPE- An Architecture for Adaptive Data-Driven Routing Prediction at the Edge",
                               "Data-driven Edge Intelligence for Robust Network Anomaly Detection"],
            "Matched Filter":["Fast Binary Network Intrusion Detection based on Matched Filter Optimization"],
            "Incremental Learning":["DAD-MCNN- DDoS Attack Detection via Multi-channel CNN",
                                    "Incremental SVM based on reserved set for network intrusion detection",
                                    "Research of Intrusion Detection Method Based on IL-FSVM",
                                    "DeepDDoS- Online DDoS Attack Detection",
                                    "Network intrusion detection using equality constraine d-optimization-base d extreme learning machines"],
            "Parallelism and Multithreading":["A Novel Hierarchical Parallelism for Accelerating NIDS Using GPUs",
                                              "Design Consideration of Network Intrusion Detection System using Hadoop and GPGPU",
                                               "A New Architecture for Network Intrusion Detection and Prevention",
                                              "Improving network intrusion detection system performance through quality of service configuration and parallel technology",
                                              "MIDeA- A Multi-Parallel Intrusion Detection Architecture"],
            "Cloud Computing":["Towards Near-Real-Time Intrusion Detection for IoT Devices using Supervised Learning and Apache Spark",
                               "Development of a Network Intrusion Detection System Using Apache Hadoop and Spark",
                               "Intrusion Detection Using Big Data and Deep Learning Techniques",
                               "A Framework for Fast and Efficient Cyber Security Network Intrusion Detection using Apache Spark",
                               "Real-time Support Vector Machine Based Network Intrusion Detection System Using Apache Storm",
                               "Performance evaluation of intrusion detection based on machine learning using Apache Spark"]},
"Dynamic Data":{"Stream Data Models":["Ensemble-Based Online Machine Learning Algorithms for Network Intrusion Detection Systems Using Streaming Data",
                                      "Learning concept-drifting data streams with random ensemble decision trees",
                                      "Real-time feature selection technique with concept drift detection using adaptive micro-clusters for data stream mining",
                                      "GPU-accelerated Outlier Detection for Continuous Data Streams",
                                      "Unsupervised Outlier Detection in Streaming Data Using Weighted Clustering",
                                      "An incremental intrusion detection system using a new semisupervised stream classification method"],
                "Reinforcement Learning":["Deep Reinforcement Learning based Intrusion Detection System for Cloud Infrastructure",
                                          "A New Approach for Adaptive Intrusion Detection"],
                 "Incremental Learning": ["ANID-SEoKELM-Adaptive network intrusion detection based on selective ensemble of kernel ELMs with random features",
                                          "Network-Traffic Anomaly Detection with Incremental Majority Learning",
                                          "Incremental Anomaly Detection in Graphs",
                                          "Detecting Bots via Incremental LS-SVM Learning with Dynamic Feature Adaptation",
                                          "Incremental k-NN SVM Method in Intrusion Detection",
                                          "A Novel Online Incremental Learning Intrusion Prevention System",
                                          "Mining network data for intrusion detection through combining SVMs with ant colony networks",
                                          "Adaptive Network Intrusion Detection System using a Hybrid Approach",
                                          "A population-based incremental learning approach with artificial immune system for network intrusion detection"]},
"Small Data":{"Meta-Learning":["A Method of Few-Shot Network Intrusion Detection Based on Meta-Learning Framework",
                               "A Hybrid Intelligent Approach for Network Intrusion Detection",
                               "Research on Intrusion Detection Model Using Ensemble learning Methods",
                               "Improved Network Traffic Classification Using Ensemble Learning",
                               "An advanced method for detection of botnet traffic using Intrusion Detection System",
                               "Intrusion Detection Using Error Correcting Output Code Based Ensemble",
                               "Data Randomization and Cluster-Based Partitioning for Botnet Intrusion Detection"],
             "Transfer Learning":["Mimic Learning to Generate a Shareable Network Intrusion Detection Model",
                                 "CANTransfer- Transfer Learning based Intrusion Detection on a Controller Area Network using Convolutional LSTM Network",
                                  "Feature-Based Transfer Learning for Network Security",
                                  "Transfer learning for detecting unknown network attacks",
                                  "Leveraging Image Representation of Network Traffic Data and Transfer Learning in Botnet Detection"],
             "Hierarchical Network": ["Network Intrusion Detection- Based on Deep Hierarchical Network and Original Flow Data"],
              "Sub-sampling": ["Newest Collaborative and Hybrid Network Intrusion Detection Framework Based on Suricata and Isolation Forest Algorithm"],
              "Data Fusion":["A Novel Multimodal-Sequential Approach Based on Multi-View Features for Network Intrusion Detection",
                             "Deep and Machine Learning Approaches for Anomaly-Based Intrusion Detection of Imbalanced Network Traffic",
                             "Network Intrusion Detection and its Strategic Importance",
                             "Research on the Intrusion Detection Technology with Hybrid Model",
                              "Fusion of ANN and SVM Classifiers for Network Attack Detection",
                             "Data Fusion Detection Model Based on SVM and Evidence Theory"]
             }
}

# %%
def count(d,c):
    for key in d.keys():
        if type(d[key]) == list:
            c[0] += len(d[key])
        elif type(d[key]) == dict:
            count(d[key],c)
c = [0]
count(categories,c)

# %%
c[0]
# Out:
# 159

# %%
len(os.listdir("../literature/Taxonomy/Collected"))==c[0]
# Out:
# False

# %%
def getdwrapper(d,L):
    if (d == {}):
        return L
    else:
        for i,key in enumerate(d):
            if (type(d[key]) == dict):
                if (i < len(d.keys())):
                    getdwrapper(d[key],L)
                elif (type(d[key]) == list):
                    return L
            else:
                L += d[key]
        return L

def getd(d):
    return getdwrapper(d,[])

p = dict()
for x in getd(categories):
    if (p.get(x) != None):
        p[x] += 1
    else:
        p[x] = 1
list(filter(lambda k: p[k] > 1, p))
# Out:
# []

# %%
set_articles_dict_topic = dict()
for key in categories:
    L = []
    for subkey in categories[key]:
        L += categories[key][subkey]
    set_articles_dict_topic[key] = set(L)

# %%
set_articles_dict_topic
# Out:
# {'Lack of Real-World Network Data': {'A Credible Network Intrusion Detection System Based on Grid',
#   'An Intrusion Detection System Based on Honeypot Technology',
#   'Clustering of Snort Alerts to Identify Patterns and Reduce Analyst Workload',
#   'Detecting Return-to-libc Buffer Overflow Attacks Using Network Intrusion Detection Systems',
#   'Generating realistic intrusion detection system dataset based on fuzzy qualitative modeling',
#   'Hypervisor-based cloud intrusion detection through online multivariate statistical change tracking',
#   'Intrusion Detection System Using Honeypots and Swarm Intelligence',
#   'LITNET-2020- An Annotated Real-World Network Flow Dataset for Network Intrusion Detection',
#   'NICE- Network Intrusion Detection and Countermeasure Selection in Virtual Network Systems',
#   'Real time dataset generation framework for intrusion detection systems in IoT',
#   'Researches on the IPv6 Network Safeguard Linked System',
#   "UGR'16- A New Dataset for the Evaluation of Cyclostationarity-Based Network IDSs",
#   'UNSW-NB15- A Comprehensive Data set for Network Intrusion Detection systems',
#   'Virtual Machine Monitor-Based Lightweight Intrusion Detection',
#   'vNIDS- Towards Elastic Security with Safe and Efficient Virtualization of Network Intrusion Detection Systems'},
#  'Noisy Data': {'A New Method of Fuzzy Support Vector Machine Algorithm for Intrusion Detection',
#   'A Novel Semi-Supervised Learning Approach for Network Intrusion Detection on Cloud-Based Robotic System',
#   'A local density-based approach for outlier detection',
#   'PCA filtering and probabilistic SOM for network intrusion detection',
#   'Semi-Supervised K-Means DDoS Detection Method Using Hybrid Feature Selection Algorithm',
#   'Toward an Online Network Intrusion Detection System Based on Ensemble Learning'},
#  'Redundant Data': {'A Discretized Extended Feature Space (DEFS) Model to Improve the Anomaly Detection Performance in Network Intrusion Detection Systems',
#   'A GA-LR wrapper approach for feature selection in network intrusion detection',
#   'A Naive Feature Selection Method and Its Application in Network Intrusion Detection',
#   'A hybrid network intrusion detection system using simplified swarm optimization (SSO)',
#   'A network intrusion detection system based on a Hidden Naive Bayes multiclass classifier',
#   'A novel architecture combined with optimal parameters for back propagation neural networks applied to anomaly network intrusion detection',
#   'A novel feature-selection approach based on the cuttlefish optimization algorithm for intrusion detection systems',
#   'A novel intrusion detection system based on hierarchical clustering and support vector machines',
#   'Adaptive intrusion detection via GA-GOGMM-based pattern learning with fuzzy rough set-based attribute selection',
#   'An efficient feature selection based Bayesian and Rough set approach for intrusion detection',
#   'BAT- Deep Learning Methods on Network Intrusion Detection Using NSL-KDD Dataset',
#   'Cyber intrusion detection by combined feature selection algorithm',
#   'Deep Learning Approach Combining Sparse Autoencoder With SVM for Network Intrusion Detection',
#   'Detection of Cyberattacks in Industrial Control systems using Enhanced Principal Component Analysis and Hypergraph based Convolution Neural Network (EPCA-HG-CNN)',
#   'Development of Rough Set- Hypergraph Technique for Key Feature Identification in Intrusion Detection Systems',
#   'Dimensionality reduction using Principal Component Analysis for network intrusion detection',
#   'Dimensionality reduction with IG-PCA and ensemble classifier for network intrusion detection',
#   'Effects-based feature identification for network intrusion detection',
#   'Evaluating Deep Learning Based Network Intrusion Detection System in Adversarial Environment',
#   'Evolving deep learning architectures for network intrusion detection using a double PSO metaheuristic',
#   'Feature Selection Based on Rough Set and Modified Genetic Algorithm for Intrusion Detection',
#   'HELAD- A novel network anomaly detection model based on heterogeneous ensemble learning',
#   'Intelligent temporal classification and fuzzy rough set-based feature selection algorithm for intrusion detection system in WSNs',
#   'Intrusion Detection using Naive Bayes Classifier with Feature Reduction',
#   'Machine-Learning-Based Feature Selection Techniques for Large-Scale Network Intrusion Detection',
#   'Network Intrusion Detection Based on PSO-Xgboost Model',
#   'Network intrusion detection system based on recursive feature addition and bigram technique',
#   'Selection of Effective Features for BGP Anomaly Detection',
#   'The Detection of Network Intrusion Based on Improved Adaboost Algorithm',
#   'The significant features of the UNSW-NB15 and the KDD99 data sets for Network Intrusion Detection Systems',
#   'Towards a Reliable Comparison and Evaluation of Network Intrusion Detection Systems Based on Machine Learning Approaches',
#   'Wireless Network Intrusion Detection Based on Improved Convolutional Neural Network'},
#  'Weakly Correlated Data': {'Robust detection for network intrusion of industrial IoT based on multi-CNN fusion'},
#  'Too Few Labeled Data': {'A Novel Two-Stage Deep Learning Model for Efficient Network Intrusion Detection',
#   'Addressing Adversarial Attacks Against Security Systems Based on Machine Learning',
#   'Defending network intrusion detection systems against adversarial evasion attacks',
#   'Evading botnet detectors based on flows and Random Forest with adversarial samples',
#   'Flow-based network traffic generation using Generative Adversarial Networks',
#   'Generative Adversarial Networks For Launching and Thwarting Adversarial Attacks on Network Intrusion Detection Systems',
#   'Improved competitive learning neural networks for network intrusion and fraud detection',
#   'Intrusion Detection Algorithm Based On Semi-supervised Learning',
#   'Investigating Adversarial Attacks against Network Intrusion Detection Systems in SDNs',
#   'Network Anomaly Detection inside Consumer Networks- A Hybrid Approach',
#   'Nonparametric Semi-Supervised Learning for Network Intrusion Detection- Combining Performance Improvements with Realistic In-Situ Training',
#   'Overcoming the Lack of Labeled Data- Training Intrusion Detection Models using Transfer Learning',
#   'PAC-GAN- Packet Generation of Network Traffic using Generative Adversarial Networks',
#   'Research on Intrusion Detection method based on SVM Co-training',
#   'Semi-Supervised Learning based Security to Detect and Mitigate Intrusions in IoT Network',
#   'Unsupervised Network Intrusion Detection Systems- Detecting the Unknown without Knowledge'},
#  'Imbalanced Data': {'1D CNN based network intrusion detection with normalization on imbalanced data',
#   'A Semi-Boosted Nested Model With Sensitivity-Based Weighted Binarization for Multi-Domain Network Intrusion Detection',
#   'An Adaptive Ensemble Machine Learning Model for Intrusion Detection',
#   'An effective convolutional neural network based on SMOTE and Gaussian mixture model for intrusion detection in imbalanced dataset',
#   'An improved NSGA-III algorithm for feature selection used in intrusion detection',
#   'An integrated Intrusion Detection Model using consistency based feature selection and LPBoost',
#   'Anomaly-Based Network Intrusion Detection Using SVM',
#   'CNN-Based Network Intrusion Detection against Denial-of-Service Attacks',
#   'Data Processing and Model Selection for Machine Learning-based Network Intrusion Detection',
#   'Genetic Fuzzy System For Intrusion Detection - Analysis of Improving of multiclass classification accuracy using KDDCup-99 imbalance dataset',
#   'Hierarchical intrusion detection using machine learning and knowledge model',
#   'Malware Detection Using Genetic Programming',
#   'Network Intrusion Detection Based on Supervised Adversarial Variational Auto-Encoder With Regularization',
#   'Network Intrusion Detection Combined Hybrid Sampling With Deep Hierarchical Network',
#   'Network Intrusion Detection System using Genetic Network Programming with Support Vector Machine',
#   'On the combination of genetic fuzzy systems and pairwise learning for improving detection rates on Intrusion Detection Systems',
#   'PCCN- Parallel Cross Convolutional Neural Network for Abnormal Network Traffic Flows Detection in Multi-Class Imbalanced Network Traffic Flows',
#   'Siam-IDS- Handling class imbalance problem in Intrusion Detection Systems using Siamese Neural Network'},
#  'Big Data': {'A Cooperative and Hybrid Network Intrusion Detection Framework in Cloud Computing Based on Snort and Optimized Back Propagation Neural Network',
#   'A Deep Learning Approach to Network Intrusion Detection',
#   'A Framework for Fast and Efficient Cyber Security Network Intrusion Detection using Apache Spark',
#   'A New Architecture for Network Intrusion Detection and Prevention',
#   'A Novel Hierarchical Parallelism for Accelerating NIDS Using GPUs',
#   'An Authorized Access Attack Detection Method for Realtime Intrusion Detection System',
#   'An Effective Feature Selection Approach for Network Intrusion Detection',
#   'An Efficient Flow Control Approach for SDN-based Network Threat Detection and Migration Using Support Vector Machine',
#   'An Intrusion Detection System Using a Deep Neural Network With Gated Recurrent Units',
#   'An efficient network intrusion detection',
#   'Anomalous query access detection in RBAC-administered databases with random forest and PCA',
#   'DAD-MCNN- DDoS Attack Detection via Multi-channel CNN',
#   'Data-driven Edge Intelligence for Robust Network Anomaly Detection',
#   'DeepDDoS- Online DDoS Attack Detection',
#   'Design Consideration of Network Intrusion Detection System using Hadoop and GPGPU',
#   'Development of a Network Intrusion Detection System Using Apache Hadoop and Spark',
#   'Fast Binary Network Intrusion Detection based on Matched Filter Optimization',
#   'Improved Salp Swarm Algorithm based on opposition based learning and novel local search algorithm for feature selection',
#   'Improving network intrusion detection system performance through quality of service configuration and parallel technology',
#   'Incremental SVM based on reserved set for network intrusion detection',
#   'Inductive Intrusion Detection in Flow-Based Network Data using One-Class Support Vector Machines',
#   'Intrusion Detection Using Big Data and Deep Learning Techniques',
#   'Large High Dimensional Data Handing Using Data Reduction',
#   'MIDeA- A Multi-Parallel Intrusion Detection Architecture',
#   'Network Intrusion Detection Based on LDA for Payload Feature Selection',
#   'Network Intrusion Detection using Hybrid Machine Learning',
#   'Network intrusion detection using equality constraine d-optimization-base d extreme learning machines',
#   'Performance evaluation of intrusion detection based on machine learning using Apache Spark',
#   'R1SVM- A Randomised Nonlinear Approach to Large-Scale Anomaly Detection',
#   'Real-time Support Vector Machine Based Network Intrusion Detection System Using Apache Storm',
#   'Research of Intrusion Detection Method Based on IL-FSVM',
#   'RoPE- An Architecture for Adaptive Data-Driven Routing Prediction at the Edge',
#   'Sampling Techniques to Accelerate Pattern Matching in Network Intrusion Detection Systems',
#   'Towards Near-Real-Time Intrusion Detection for IoT Devices using Supervised Learning and Apache Spark'},
#  'Dynamic Data': {'A New Approach for Adaptive Intrusion Detection',
#   'A Novel Online Incremental Learning Intrusion Prevention System',
#   'A population-based incremental learning approach with artificial immune system for network intrusion detection',
#   'ANID-SEoKELM-Adaptive network intrusion detection based on selective ensemble of kernel ELMs with random features',
#   'Adaptive Network Intrusion Detection System using a Hybrid Approach',
#   'An incremental intrusion detection system using a new semisupervised stream classification method',
#   'Deep Reinforcement Learning based Intrusion Detection System for Cloud Infrastructure',
#   'Detecting Bots via Incremental LS-SVM Learning with Dynamic Feature Adaptation',
#   'Ensemble-Based Online Machine Learning Algorithms for Network Intrusion Detection Systems Using Streaming Data',
#   'GPU-accelerated Outlier Detection for Continuous Data Streams',
#   'Incremental Anomaly Detection in Graphs',
#   'Incremental k-NN SVM Method in Intrusion Detection',
#   'Learning concept-drifting data streams with random ensemble decision trees',
#   'Mining network data for intrusion detection through combining SVMs with ant colony networks',
#   'Network-Traffic Anomaly Detection with Incremental Majority Learning',
#   'Real-time feature selection technique with concept drift detection using adaptive micro-clusters for data stream mining',
#   'Unsupervised Outlier Detection in Streaming Data Using Weighted Clustering'},
#  'Small Data': {'A Hybrid Intelligent Approach for Network Intrusion Detection',
#   'A Method of Few-Shot Network Intrusion Detection Based on Meta-Learning Framework',
#   'A Novel Multimodal-Sequential Approach Based on Multi-View Features for Network Intrusion Detection',
#   'An advanced method for detection of botnet traffic using Intrusion Detection System',
#   'CANTransfer- Transfer Learning based Intrusion Detection on a Controller Area Network using Convolutional LSTM Network',
#   'Data Fusion Detection Model Based on SVM and Evidence Theory',
#   'Data Randomization and Cluster-Based Partitioning for Botnet Intrusion Detection',
#   'Deep and Machine Learning Approaches for Anomaly-Based Intrusion Detection of Imbalanced Network Traffic',
#   'Feature-Based Transfer Learning for Network Security',
#   'Fusion of ANN and SVM Classifiers for Network Attack Detection',
#   'Improved Network Traffic Classification Using Ensemble Learning',
#   'Intrusion Detection Using Error Correcting Output Code Based Ensemble',
#   'Leveraging Image Representation of Network Traffic Data and Transfer Learning in Botnet Detection',
#   'Mimic Learning to Generate a Shareable Network Intrusion Detection Model',
#   'Network Intrusion Detection and its Strategic Importance',
#   'Network Intrusion Detection- Based on Deep Hierarchical Network and Original Flow Data',
#   'Newest Collaborative and Hybrid Network Intrusion Detection Framework Based on Suricata and Isolation Forest Algorithm',
#   'Research on Intrusion Detection Model Using Ensemble learning Methods',
#   'Research on the Intrusion Detection Technology with Hybrid Model',
#   'Transfer learning for detecting unknown network attacks'}}

# %%
articles_dict_topic = dict()
for key in categories:
    for subkey in categories[key]:
        for paper in categories[key][subkey]:
            articles_dict_topic[paper] = key

# %%
# def get_strs_wrapper(L_,strs):
#     if (L_ == []):
#         return strs
#     else:
#         if (type(L_[0]) == list):
#             return get_strs_wrapper(L_[0],strs)+get_strs_wrapper(L_[1:],strs) 
#         else:
#             return get_strs_wrapper(L_[1:],strs+L_[0].split())
# def get_strs(L_):
#     return get_strs_wrapper(L_,[])

#get_strs([["ls -al",["df -h","cd ~","exit"]],[["whoami","exit"]],[[["cd ~/Desktop","ls"],"ls -al"],["exit"]],["df -h","diskutil unmount /dev1/something"]])
articles_dict_topic
# Out:
# {'Intrusion Detection System Using Honeypots and Swarm Intelligence': 'Lack of Real-World Network Data',
#  'Researches on the IPv6 Network Safeguard Linked System': 'Lack of Real-World Network Data',
#  'An Intrusion Detection System Based on Honeypot Technology': 'Lack of Real-World Network Data',
#  'Generating realistic intrusion detection system dataset based on fuzzy qualitative modeling': 'Lack of Real-World Network Data',
#  'UNSW-NB15- A Comprehensive Data set for Network Intrusion Detection systems': 'Lack of Real-World Network Data',
#  'Hypervisor-based cloud intrusion detection through online multivariate statistical change tracking': 'Lack of Real-World Network Data',
#  'Real time dataset generation framework for intrusion detection systems in IoT': 'Lack of Real-World Network Data',
#  'Detecting Return-to-libc Buffer Overflow Attacks Using Network Intrusion Detection Systems': 'Lack of Real-World Network Data',
#  'A Credible Network Intrusion Detection System Based on Grid': 'Lack of Real-World Network Data',
#  'Virtual Machine Monitor-Based Lightweight Intrusion Detection': 'Lack of Real-World Network Data',
#  'NICE- Network Intrusion Detection and Countermeasure Selection in Virtual Network Systems': 'Lack of Real-World Network Data',
#  'vNIDS- Towards Elastic Security with Safe and Efficient Virtualization of Network Intrusion Detection Systems': 'Lack of Real-World Network Data',
#  'LITNET-2020- An Annotated Real-World Network Flow Dataset for Network Intrusion Detection': 'Lack of Real-World Network Data',
#  "UGR'16- A New Dataset for the Evaluation of Cyclostationarity-Based Network IDSs": 'Lack of Real-World Network Data',
#  'Clustering of Snort Alerts to Identify Patterns and Reduce Analyst Workload': 'Lack of Real-World Network Data',
#  'A New Method of Fuzzy Support Vector Machine Algorithm for Intrusion Detection': 'Noisy Data',
#  'Toward an Online Network Intrusion Detection System Based on Ensemble Learning': 'Noisy Data',
#  'PCA filtering and probabilistic SOM for network intrusion detection': 'Noisy Data',
#  'Semi-Supervised K-Means DDoS Detection Method Using Hybrid Feature Selection Algorithm': 'Noisy Data',
#  'A Novel Semi-Supervised Learning Approach for Network Intrusion Detection on Cloud-Based Robotic System': 'Noisy Data',
#  'A local density-based approach for outlier detection': 'Noisy Data',
#  'Towards a Reliable Comparison and Evaluation of Network Intrusion Detection Systems Based on Machine Learning Approaches': 'Redundant Data',
#  'Evaluating Deep Learning Based Network Intrusion Detection System in Adversarial Environment': 'Redundant Data',
#  'Selection of Effective Features for BGP Anomaly Detection': 'Redundant Data',
#  'A novel feature-selection approach based on the cuttlefish optimization algorithm for intrusion detection systems': 'Redundant Data',
#  'The Detection of Network Intrusion Based on Improved Adaboost Algorithm': 'Redundant Data',
#  'Dimensionality reduction with IG-PCA and ensemble classifier for network intrusion detection': 'Redundant Data',
#  'A GA-LR wrapper approach for feature selection in network intrusion detection': 'Redundant Data',
#  'Dimensionality reduction using Principal Component Analysis for network intrusion detection': 'Redundant Data',
#  'Effects-based feature identification for network intrusion detection': 'Redundant Data',
#  'The significant features of the UNSW-NB15 and the KDD99 data sets for Network Intrusion Detection Systems': 'Redundant Data',
#  'A novel architecture combined with optimal parameters for back propagation neural networks applied to anomaly network intrusion detection': 'Redundant Data',
#  'A novel intrusion detection system based on hierarchical clustering and support vector machines': 'Redundant Data',
#  'Network intrusion detection system based on recursive feature addition and bigram technique': 'Redundant Data',
#  'Wireless Network Intrusion Detection Based on Improved Convolutional Neural Network': 'Redundant Data',
#  'Evolving deep learning architectures for network intrusion detection using a double PSO metaheuristic': 'Redundant Data',
#  'Network Intrusion Detection Based on PSO-Xgboost Model': 'Redundant Data',
#  'A Discretized Extended Feature Space (DEFS) Model to Improve the Anomaly Detection Performance in Network Intrusion Detection Systems': 'Redundant Data',
#  'A network intrusion detection system based on a Hidden Naive Bayes multiclass classifier': 'Redundant Data',
#  'Feature Selection Based on Rough Set and Modified Genetic Algorithm for Intrusion Detection': 'Redundant Data',
#  'A Naive Feature Selection Method and Its Application in Network Intrusion Detection': 'Redundant Data',
#  'Machine-Learning-Based Feature Selection Techniques for Large-Scale Network Intrusion Detection': 'Redundant Data',
#  'Intrusion Detection using Naive Bayes Classifier with Feature Reduction': 'Redundant Data',
#  'Cyber intrusion detection by combined feature selection algorithm': 'Redundant Data',
#  'An efficient feature selection based Bayesian and Rough set approach for intrusion detection': 'Redundant Data',
#  'Adaptive intrusion detection via GA-GOGMM-based pattern learning with fuzzy rough set-based attribute selection': 'Redundant Data',
#  'Intelligent temporal classification and fuzzy rough set-based feature selection algorithm for intrusion detection system in WSNs': 'Redundant Data',
#  'Development of Rough Set- Hypergraph Technique for Key Feature Identification in Intrusion Detection Systems': 'Redundant Data',
#  'A hybrid network intrusion detection system using simplified swarm optimization (SSO)': 'Redundant Data',
#  'HELAD- A novel network anomaly detection model based on heterogeneous ensemble learning': 'Redundant Data',
#  'Deep Learning Approach Combining Sparse Autoencoder With SVM for Network Intrusion Detection': 'Redundant Data',
#  'BAT- Deep Learning Methods on Network Intrusion Detection Using NSL-KDD Dataset': 'Redundant Data',
#  'Detection of Cyberattacks in Industrial Control systems using Enhanced Principal Component Analysis and Hypergraph based Convolution Neural Network (EPCA-HG-CNN)': 'Redundant Data',
#  'Robust detection for network intrusion of industrial IoT based on multi-CNN fusion': 'Weakly Correlated Data',
#  'Semi-Supervised Learning based Security to Detect and Mitigate Intrusions in IoT Network': 'Too Few Labeled Data',
#  'Intrusion Detection Algorithm Based On Semi-supervised Learning': 'Too Few Labeled Data',
#  'Nonparametric Semi-Supervised Learning for Network Intrusion Detection- Combining Performance Improvements with Realistic In-Situ Training': 'Too Few Labeled Data',
#  'Research on Intrusion Detection method based on SVM Co-training': 'Too Few Labeled Data',
#  'Unsupervised Network Intrusion Detection Systems- Detecting the Unknown without Knowledge': 'Too Few Labeled Data',
#  'A Novel Two-Stage Deep Learning Model for Efficient Network Intrusion Detection': 'Too Few Labeled Data',
#  'Improved competitive learning neural networks for network intrusion and fraud detection': 'Too Few Labeled Data',
#  'Network Anomaly Detection inside Consumer Networks- A Hybrid Approach': 'Too Few Labeled Data',
#  'Overcoming the Lack of Labeled Data- Training Intrusion Detection Models using Transfer Learning': 'Too Few Labeled Data',
#  'Investigating Adversarial Attacks against Network Intrusion Detection Systems in SDNs': 'Too Few Labeled Data',
#  'Defending network intrusion detection systems against adversarial evasion attacks': 'Too Few Labeled Data',
#  'Flow-based network traffic generation using Generative Adversarial Networks': 'Too Few Labeled Data',
#  'Generative Adversarial Networks For Launching and Thwarting Adversarial Attacks on Network Intrusion Detection Systems': 'Too Few Labeled Data',
#  'Evading botnet detectors based on flows and Random Forest with adversarial samples': 'Too Few Labeled Data',
#  'PAC-GAN- Packet Generation of Network Traffic using Generative Adversarial Networks': 'Too Few Labeled Data',
#  'Addressing Adversarial Attacks Against Security Systems Based on Machine Learning': 'Too Few Labeled Data',
#  'An effective convolutional neural network based on SMOTE and Gaussian mixture model for intrusion detection in imbalanced dataset': 'Imbalanced Data',
#  'Data Processing and Model Selection for Machine Learning-based Network Intrusion Detection': 'Imbalanced Data',
#  '1D CNN based network intrusion detection with normalization on imbalanced data': 'Imbalanced Data',
#  'Hierarchical intrusion detection using machine learning and knowledge model': 'Imbalanced Data',
#  'Network Intrusion Detection Based on Supervised Adversarial Variational Auto-Encoder With Regularization': 'Imbalanced Data',
#  'A Semi-Boosted Nested Model With Sensitivity-Based Weighted Binarization for Multi-Domain Network Intrusion Detection': 'Imbalanced Data',
#  'An Adaptive Ensemble Machine Learning Model for Intrusion Detection': 'Imbalanced Data',
#  'Network Intrusion Detection Combined Hybrid Sampling With Deep Hierarchical Network': 'Imbalanced Data',
#  'Anomaly-Based Network Intrusion Detection Using SVM': 'Imbalanced Data',
#  'An integrated Intrusion Detection Model using consistency based feature selection and LPBoost': 'Imbalanced Data',
#  'An improved NSGA-III algorithm for feature selection used in intrusion detection': 'Imbalanced Data',
#  'PCCN- Parallel Cross Convolutional Neural Network for Abnormal Network Traffic Flows Detection in Multi-Class Imbalanced Network Traffic Flows': 'Imbalanced Data',
#  'CNN-Based Network Intrusion Detection against Denial-of-Service Attacks': 'Imbalanced Data',
#  'Siam-IDS- Handling class imbalance problem in Intrusion Detection Systems using Siamese Neural Network': 'Imbalanced Data',
#  'Malware Detection Using Genetic Programming': 'Imbalanced Data',
#  'Genetic Fuzzy System For Intrusion Detection - Analysis of Improving of multiclass classification accuracy using KDDCup-99 imbalance dataset': 'Imbalanced Data',
#  'On the combination of genetic fuzzy systems and pairwise learning for improving detection rates on Intrusion Detection Systems': 'Imbalanced Data',
#  'Network Intrusion Detection System using Genetic Network Programming with Support Vector Machine': 'Imbalanced Data',
#  'Network Intrusion Detection using Hybrid Machine Learning': 'Big Data',
#  'An Authorized Access Attack Detection Method for Realtime Intrusion Detection System': 'Big Data',
#  'A Deep Learning Approach to Network Intrusion Detection': 'Big Data',
#  'Large High Dimensional Data Handing Using Data Reduction': 'Big Data',
#  'Anomalous query access detection in RBAC-administered databases with random forest and PCA': 'Big Data',
#  'R1SVM- A Randomised Nonlinear Approach to Large-Scale Anomaly Detection': 'Big Data',
#  'Improved Salp Swarm Algorithm based on opposition based learning and novel local search algorithm for feature selection': 'Big Data',
#  'An Effective Feature Selection Approach for Network Intrusion Detection': 'Big Data',
#  'An Efficient Flow Control Approach for SDN-based Network Threat Detection and Migration Using Support Vector Machine': 'Big Data',
#  'An efficient network intrusion detection': 'Big Data',
#  'Inductive Intrusion Detection in Flow-Based Network Data using One-Class Support Vector Machines': 'Big Data',
#  'An Intrusion Detection System Using a Deep Neural Network With Gated Recurrent Units': 'Big Data',
#  'Network Intrusion Detection Based on LDA for Payload Feature Selection': 'Big Data',
#  'Sampling Techniques to Accelerate Pattern Matching in Network Intrusion Detection Systems': 'Big Data',
#  'A Cooperative and Hybrid Network Intrusion Detection Framework in Cloud Computing Based on Snort and Optimized Back Propagation Neural Network': 'Big Data',
#  'RoPE- An Architecture for Adaptive Data-Driven Routing Prediction at the Edge': 'Big Data',
#  'Data-driven Edge Intelligence for Robust Network Anomaly Detection': 'Big Data',
#  'Fast Binary Network Intrusion Detection based on Matched Filter Optimization': 'Big Data',
#  'DAD-MCNN- DDoS Attack Detection via Multi-channel CNN': 'Big Data',
#  'Incremental SVM based on reserved set for network intrusion detection': 'Big Data',
#  'Research of Intrusion Detection Method Based on IL-FSVM': 'Big Data',
#  'DeepDDoS- Online DDoS Attack Detection': 'Big Data',
#  'Network intrusion detection using equality constraine d-optimization-base d extreme learning machines': 'Big Data',
#  'A Novel Hierarchical Parallelism for Accelerating NIDS Using GPUs': 'Big Data',
#  'Design Consideration of Network Intrusion Detection System using Hadoop and GPGPU': 'Big Data',
#  'A New Architecture for Network Intrusion Detection and Prevention': 'Big Data',
#  'Improving network intrusion detection system performance through quality of service configuration and parallel technology': 'Big Data',
#  'MIDeA- A Multi-Parallel Intrusion Detection Architecture': 'Big Data',
#  'Towards Near-Real-Time Intrusion Detection for IoT Devices using Supervised Learning and Apache Spark': 'Big Data',
#  'Development of a Network Intrusion Detection System Using Apache Hadoop and Spark': 'Big Data',
#  'Intrusion Detection Using Big Data and Deep Learning Techniques': 'Big Data',
#  'A Framework for Fast and Efficient Cyber Security Network Intrusion Detection using Apache Spark': 'Big Data',
#  'Real-time Support Vector Machine Based Network Intrusion Detection System Using Apache Storm': 'Big Data',
#  'Performance evaluation of intrusion detection based on machine learning using Apache Spark': 'Big Data',
#  'Ensemble-Based Online Machine Learning Algorithms for Network Intrusion Detection Systems Using Streaming Data': 'Dynamic Data',
#  'Learning concept-drifting data streams with random ensemble decision trees': 'Dynamic Data',
#  'Real-time feature selection technique with concept drift detection using adaptive micro-clusters for data stream mining': 'Dynamic Data',
#  'GPU-accelerated Outlier Detection for Continuous Data Streams': 'Dynamic Data',
#  'Unsupervised Outlier Detection in Streaming Data Using Weighted Clustering': 'Dynamic Data',
#  'An incremental intrusion detection system using a new semisupervised stream classification method': 'Dynamic Data',
#  'Deep Reinforcement Learning based Intrusion Detection System for Cloud Infrastructure': 'Dynamic Data',
#  'A New Approach for Adaptive Intrusion Detection': 'Dynamic Data',
#  'ANID-SEoKELM-Adaptive network intrusion detection based on selective ensemble of kernel ELMs with random features': 'Dynamic Data',
#  'Network-Traffic Anomaly Detection with Incremental Majority Learning': 'Dynamic Data',
#  'Incremental Anomaly Detection in Graphs': 'Dynamic Data',
#  'Detecting Bots via Incremental LS-SVM Learning with Dynamic Feature Adaptation': 'Dynamic Data',
#  'Incremental k-NN SVM Method in Intrusion Detection': 'Dynamic Data',
#  'A Novel Online Incremental Learning Intrusion Prevention System': 'Dynamic Data',
#  'Mining network data for intrusion detection through combining SVMs with ant colony networks': 'Dynamic Data',
#  'Adaptive Network Intrusion Detection System using a Hybrid Approach': 'Dynamic Data',
#  'A population-based incremental learning approach with artificial immune system for network intrusion detection': 'Dynamic Data',
#  'A Method of Few-Shot Network Intrusion Detection Based on Meta-Learning Framework': 'Small Data',
#  'A Hybrid Intelligent Approach for Network Intrusion Detection': 'Small Data',
#  'Research on Intrusion Detection Model Using Ensemble learning Methods': 'Small Data',
#  'Improved Network Traffic Classification Using Ensemble Learning': 'Small Data',
#  'An advanced method for detection of botnet traffic using Intrusion Detection System': 'Small Data',
#  'Intrusion Detection Using Error Correcting Output Code Based Ensemble': 'Small Data',
#  'Data Randomization and Cluster-Based Partitioning for Botnet Intrusion Detection': 'Small Data',
#  'Mimic Learning to Generate a Shareable Network Intrusion Detection Model': 'Small Data',
#  'CANTransfer- Transfer Learning based Intrusion Detection on a Controller Area Network using Convolutional LSTM Network': 'Small Data',
#  'Feature-Based Transfer Learning for Network Security': 'Small Data',
#  'Transfer learning for detecting unknown network attacks': 'Small Data',
#  'Leveraging Image Representation of Network Traffic Data and Transfer Learning in Botnet Detection': 'Small Data',
#  'Network Intrusion Detection- Based on Deep Hierarchical Network and Original Flow Data': 'Small Data',
#  'Newest Collaborative and Hybrid Network Intrusion Detection Framework Based on Suricata and Isolation Forest Algorithm': 'Small Data',
#  'A Novel Multimodal-Sequential Approach Based on Multi-View Features for Network Intrusion Detection': 'Small Data',
#  'Deep and Machine Learning Approaches for Anomaly-Based Intrusion Detection of Imbalanced Network Traffic': 'Small Data',
#  'Network Intrusion Detection and its Strategic Importance': 'Small Data',
#  'Research on the Intrusion Detection Technology with Hybrid Model': 'Small Data',
#  'Fusion of ANN and SVM Classifiers for Network Attack Detection': 'Small Data',
#  'Data Fusion Detection Model Based on SVM and Evidence Theory': 'Small Data'}

# %%
parsedPDF = tika.parser.from_file(
        "../literature/Taxonomy/Collected/{}.pdf".format("PCA filtering and probabilistic SOM for network intrusion detection"),xmlContent=True)    
parsedPDF['metadata'].get('Creation-Date')
# Out:
# '2015-05-13T05:22:32Z'

# %%
import graphviz
import pygraphviz
import networkx as nx
from networkx.drawing.nx_agraph import to_agraph

# %%
import enchant
english_dictionary = enchant.Dict("en_US")

# %%
unknown_publishers = {'Defending network intrusion detection systems against adversarial evasion attacks':'Elsevier',
    'Deep Learning Approach Combining Sparse Autoencoder With SVM for Network Intrusion Detection':'IEEE',
    'A Discretized Extended Feature Space (DEFS) Model to Improve the Anomaly Detection Performance in Network Intrusion Detection Systems': "SCITEPRESS",
"Network Intrusion Detection Based on Supervised Adversarial Variational Auto-Encoder With Regularization":"IEEE",
"Towards Near-Real-Time Intrusion Detection for IoT Devices using Supervised Learning and Apache Spark":"MDPI",
"An efficient network intrusion detection":"Elsevier",
"Ensemble-Based Online Machine Learning Algorithms for Network Intrusion Detection Systems Using Streaming Data":"MDPI",
"Intrusion Detection System Using Honeypots and Swarm Intelligence":"ACM",
"Research of Intrusion Detection Method Based on IL-FSVM":"IEEE",
"Evaluating Deep Learning Based Network Intrusion Detection System in Adversarial Environment":"IEEE",
"An effective convolutional neural network based on SMOTE and Gaussian mixture model for intrusion detection in imbalanced dataset":"Elsevier",
"Detecting Bots via Incremental LS-SVM Learning with Dynamic Feature Adaptation":"ACM",
"Network Anomaly Detection inside Consumer Networks-A Hybrid Approach":"MDPI",
"An efficient feature selection based Bayesian and Rough set approach for intrusion detection":"Elsevier",
"Leveraging Image Representation of Network Traffic Data and Transfer Learning in Botnet Detection":"MDPI",
"DAD-MCNN- DDoS Attack Detection via Multi-channel CNN":"ACM",
"Real time dataset generation framework for intrusion detection systems in IoT":"Elsevier",
"PCCN- Parallel Cross Convolutional Neural Network for Abnormal Network Traffic Flows Detection in Multi-Class Imbalanced Network Traffic Flows":"IEEE",
"A New Architecture for Network Intrusion Detection and Prevention":"IEEE",
"A Novel Two-Stage Deep Learning Model for Efficient Network Intrusion Detection":"IEEE",
"vNIDS- Towards Elastic Security with Safe and Efficient Virtualization of Network Intrusion Detection Systems":"ACM",
"A Novel Semi-Supervised Learning Approach for Network Intrusion Detection on Cloud-Based Robotic System":"IEEE",
"An Adaptive Ensemble Machine Learning Model for Intrusion Detection":"IEEE",
"The Detection of Network Intrusion Based on Improved Adaboost Algorithm":"ACM",
"A modified neuro-fuzzy classifier and its parallel implementation on modern GPUs for real time intrusion detection":"Elsevier",
"An Intrusion Detection System Using a Deep Neural Network With Gated Recurrent Units":"IEEE",
"Improving outliers detection in data streams using LiCS and voting":"Elsevier",
"Semi-Supervised K-Means DDoS Detection Method Using Hybrid Feature Selection Algorithm":"IEEE",
"Intrusion Detection Using Big Data and Deep Learning Techniques":"ACM",
"Wireless Network Intrusion Detection Based on Improved Convolutional Neural Network":"IEEE",
"CNN-Based Network Intrusion Detection against Denial-of-Service Attacks":"MDPI",
"UGR'16- A New Dataset for the Evaluation of Cyclostationarity-Based Network IDSs":"Elsevier",
"A Framework for Fast and Efficient Cyber Security Network Intrusion Detection using Apache Spark":"Elsevier",
"Feature-Based Transfer Learning for Network Security":"IEEE",
"A Semi-Boosted Nested Model With Sensitivity-Based Weighted Binarization for Multi-Domain Network Intrusion Detection":"ACM",
"Network Intrusion Detection Based on PSO-Xgboost Model":"IEEE",
"Newest Collaborative and Hybrid Network Intrusion Detection Framework Based on Suricata and Isolation Forest Algorithm":"ACM",
"R1SVM- A Randomised Nonlinear Approach to Large-Scale Anomaly Detection":"AAAI",
"A Hybrid Intelligent Approach for Network Intrusion Detection":"Elsevier",
"Generating realistic intrusion detection system dataset based on fuzzy qualitative modeling":"Elsevier",
"Transfer learning for detecting unknown network attacks":"Springer",
"CANTransfer – Transfer Learning based Intrusion Detection on a Controller Area Network using Convolutional LSTM Network":"ACM",
"Hierarchical intrusion detection using machine learning and knowledge model":"MDPI",
"A novel feature-selection approach based on the cuttlefish optimization algorithm for intrusion detection systems":"Elsevier",
"Incremental k-NN SVM Method in Intrusion Detection":"IEEE",
"An advanced method for detection of botnet traffic using Intrusion Detection System":"IEEE",
"LITNET-2020- An Annotated Real-World Network Flow Dataset for Network Intrusion Detection":"MDPI",
"ANID-SEoKELM-Adaptive network intrusion detection based on selective ensemble of kernel ELMs with random features":"Elsevier",
"BAT- Deep Learning Methods on Network Intrusion Detection Using NSL-KDD Dataset":"IEEE",
"Network Intrusion Detection System using Genetic Network Programming with Support Vector Machine":"ACM",
"MIDeA- A Multi-Parallel Intrusion Detection Architecture":"ACM",
"Addressing Adversarial Attacks Against Security Systems Based on Machine Learning":"IEEE",
"Network Intrusion Detection- Based on Deep Hierarchical Network and Original Flow Data":"IEEE",
"Real-time feature selection technique with concept drift detection usingadaptive micro-clusters for data stream mining":"Elsevier",
"Network Intrusion Detection Combined Hybrid Sampling With Deep Hierarchical Network":"IEEE",
"Development of a Network Intrusion Detection System Using Apache Hadoop and Spark":"IEEE",
"Nonparametric Semi-Supervised Learning for Network Intrusion Detection- Combining Performance Improvements with Realistic In-Situ Training":"ACM",
"Virtual Machine Monitor-Based Lightweight Intrusion Detection":"ACM",
"Overcoming the Lack of Labeled Data- Training Intrusion Detection Models using Transfer Learning":"IEEE",
"A Novel Multimodal-Sequential Approach Based on Multi-View Features for Network Intrusion Detection":"IEEE",
"A New Method of Fuzzy Support Vector Machine Algorithm for Intrusion Detection":"MDPI",
"Towards a Reliable Comparison and Evaluation of Network Intrusion Detection Systems Based on Machine Learning Approaches":"MDPI",
"Fusion of ANN and SVM Classifiers for Network Attack Detection":"IEEE",
"Robust detection for network intrusion of industrial IoT based on multi-CNN fusion":"Elsevier",
"Improved Network Traffic Classification Using Ensemble Learning":"IEEE",
"Network Anomaly Detection inside Consumer Networks- A Hybrid Approach":"MDPI",
"An incremental intrusion detection system using a new semisupervised stream classification method":"Wiley"}

unknown_pubkeys = set(unknown_publishers.keys())

# %%
publishers = []
for file in os.listdir("../literature/Taxonomy/Collected"):
    if file != ".DS_Store":
        inputfile = "../literature/Taxonomy/Collected/{}".format(file)
        reader_pdf = PyPDF2.PdfFileReader(inputfile,strict=False)
        pdf_xmp = reader_pdf.getXmpMetadata()
        xmp_names = ["custom_properties","dc_contributor","dc_coverage","dc_creator","dc_date",
                     "dc_description","dc_format","dc_identifier","dc_language","dc_publisher"]
        parsedPDF = tika.parser.from_file(inputfile, xmlContent = True)
        xmp_dict = {}
        for name in xmp_names:
            try:
                xmp_dict[name] = getattr(pdf_xmp, name)
            except:
                xmp_dict[name] = "Unknown"
        if (file[:-4] in unknown_pubkeys):
            publishers += [tuple([file[:-4],unknown_publishers[file[:-4]]])]
        else:
            if (len(xmp_dict["dc_publisher"]) == 0):
                print(file)
            publishers += [tuple([file[:-4],xmp_dict["dc_publisher"][0].split()[0] if (len(xmp_dict["dc_publisher"]) != 0) else ""])]
# Out:
# CANTransfer- Transfer Learning based Intrusion Detection on a Controller Area Network using Convolutional LSTM Network.pdf

# %%
class ArticleHandler(object):
    def __init__(self,directory:str, data:pd.core.frame.DataFrame = pd.DataFrame({"article_title":[],"text":[], "creation_date":[], "article_length":[], "publisher":[],"topic":[]})):
        self.dir = directory
        # pre-existing data or from scratch
        self.data = data
        self.articles_ordered = []
    # REQ: path_to_pdf being a valid path not starting with /
    # ENS: s ==> string containing text extracted from the specified pdf.
    def parse_pdf(self,path_to_pdf:str,article_class=None)->str:
        def get_val(s):
            i1 = s.lower().find("introduction")
            val = None
            if (i1 != -1):
                val = s[:i1]
            else:
                i2 = s.lower().find("summary")
                if (i2 != -1):
                    val = s[:i2]
                else:
                    i3 = s.lower().find("current study")
                    if (i3 != -1):
                        val = s[:i3]
                    else:
                        i4 = s.lower().find("background")
                        val = s[:i4]
            return val
        inputfile = self.dir+"/"+path_to_pdf
        parsedPDF = tika.parser.from_file(inputfile, xmlContent = True)
        L = list(filter(lambda x: (len(x) > 30),list(map(lambda x: x.text, BeautifulSoup(parsedPDF['content'],"html.parser").find_all('p')))))
        text = " ".join(" ".join(L).split("\n"))
        text = text.replace("- ", "")
        text = text.replace(" - ", "-")
        text = text.replace(" -", " ")
        s = parsedPDF['metadata'].get('resourceName')
        if (type(s) == list): 
            s = s[0]
            if (s.startswith("b'")):
                s = s[2:len(s)-1]
            else:
                s = s[1:]
        else: 
            if (s.startswith("b'")):
                s = s[2:len(s)-1]
            else:
                s = s[1:] # then s should be a string

        if (s.endswith(".pdf")):
            s = s[:-4]

        t = get_val(text)
        if (parsedPDF['metadata'].get('Creation-Date') == None):
            print(path_to_pdf)
        top_ = None
        for topic in set_articles_dict_topic:
            if s in set_articles_dict_topic[topic]:
                top_ = topic
                break
        new_row = {"article_title": s,
                   "text": t.lower(),
                   "creation_date": parsedPDF['metadata'].get('Creation-Date'),
                   "article_length": parsedPDF['metadata'].get('xmpTPg:NPages'),
                   "publisher": publishers,
                   "topic":top_}
        if (article_class != None and article_class == articles_dict_topic[s]):
            self.data = self.data.append(new_row, ignore_index=True)
        elif (article_class == None):
            self.data = self.data.append(new_row, ignore_index=True)
    # REQ: True
    # ENS: (result,n) ==> tuple of string specifying the string result from the directory that 
    # was parsed and an integer indicating the number of articles 
    def parse_dir(self,category):
        result = []
        i = 0
        def parse_dir_recur(curr_dir):
            for item in os.listdir(curr_dir):
                if os.path.isdir(curr_dir+"/"+item):
                    parse_dir_recur(curr_dir+"/"+item)
                elif (os.path.isfile(curr_dir+"/"+item) and item != ".DS_Store"):
                    self.parse_pdf(item, category)
        parse_dir_recur(self.dir)
        self.data = self.data.dropna()
    def get_data(self):
        return self.data
    def to_csv(self,name):
        self.data.to_csv("{}.csv".format(name))
    def order_by(self, by="creation_date",category=None):
        L = []
        for i in range(len(self.data)-1,-1,-1):
            if (self.data.iloc[i][by] == "" or self.data.iloc[i][by] == None):
                self.data.drop([i])
            else:
                L += [list(self.data.iloc[i][["article_title",by]])]
        if (category==None):
            self.articles_ordered = sorted(list(L),key=lambda x: x[1])
        else:
            s = set(getd(categories[category]))
            self.articles_ordered = sorted(list(filter(lambda x: x[0] in s, L)),key=lambda x: x[1])
        return sorted(list(L),key=lambda x: x[1])
    def get_time_graph(self,n):
        G = nx.Graph()
        col = "red"
        end = False
        for i,_ in enumerate(list(range(n))+list(range(len(self.articles_ordered)-1-n,len(self.articles_ordered)-1))): 
            if i >= n and (not end):
                end = True
                col = "blue"
            name1, name2 = self.articles_ordered[i][0], self.articles_ordered[i+1][0]
            G.add_node(name1,color=col)
            G.add_node(name2,color=col)
            G.add_edge(name1,name2,color="black")
        A = to_agraph(G)
        A.layout()
        A.draw('./graphs/time_graph.png')
        self.graph = A
    def make_model_articles(self,n):
        def majority_in_dict_not_in_s(x,n):
            words = x.split()
            in_dict = 0
            not_in_s = 0
            for word in words:
                if english_dictionary.check(word):
                    in_dict += 1
                if word not in s:
                    not_in_s += 1
            return (in_dict >= 0.5*n) and (not_in_s == n)
        def alpha(x):
            words = x.split()
            for word in words:
                if not word.isalpha():
                    return False
            return True
        # CBOW and Skip Gram Model for 
        # Word Vector Embeddings
        # first gensim
        L = articles.data["text"].apply(lambda x: re.sub("\b\d+\b"," ",str(x)))
        L = list(articles.data["text"].apply(lambda x: list(map(lambda tup: " ".join(list(tup)) ,
            list(ngrams(nltk.word_tokenize(re.sub(r'[^\w\s]',"",str(x))), n)))) ))
        L = list(map(lambda subLst: list(filter(lambda x: (alpha(x)) and majority_in_dict_not_in_s(x,n), subLst)),L))
        self.model = Word2Vec(L, size=2, window=4, sg=1, min_count=1)
    def csv_to_data(self,csv_name):
        self.data = pd.read_csv(csv_name)
        return self.data
    def tfidf_vectorize(self):
#         def max_count(sentence:list):
#             d = dict()
#             for word_ in sentence:
#                 if (d.get(word_) != None):
#                     d[word_] += 1
#                 else:
#                     d[word_] = 1
#             return (max(d.values()),counts)
#         mx_count,counts = max_count(sentence)
#         for word in sentence:
#             tf = 0.5+0.5*(counts[word]/mx_count_in_specific_document) # double normalization 
#             idf = np.log(total_num_documents/num_documents_with_word)
#.            - tf(term,document_i)*idf(term,all_documents)
        corpus = list(self.data["text"])
        vectorizer = TfidfVectorizer()
        data = vectorizer.fit_transform(corpus)
    def get_similarity(self,phrase1,phrase2):
        vectors = [self.model.wv[word] for word in self.model.wv.vocab.keys()]
        df = pd.DataFrame(vectors, columns=['x', 'y'], index=self.model.wv.vocab.keys())
        sns.relplot(x="x", 
                    y="y",
                    palette="Greens_r", 
                    data=df)
articles = ArticleHandler("../literature/Taxonomy/Collected")
articles.parse_dir("Noisy Data")
#articles.order_by(category="Big Data")
#articles.get_time_graph(5)
articles.to_csv("taxonomy_articles")

# %%
c = articles.csv_to_data("taxonomy_articles.csv")

# %%
a = articles.make_model_articles(3)

# %%
articles.model.build_vocab([["weakly correlated data"],
                      ["noisy data"], 
                      ["lack of real-world data"],
                      ["redundant data"],
                      ["too few labeled data"],
                      ["imbalanced data"],
                      ["big data"],
                      ["dynamic data"],
                      ["small data"]], update=True)

# %%
lst = articles.model.similar_by_vector(articles.model["noisy data"],topn=10000)
lst
# Out:
# DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead). [ipykernel_launcher.py:1]
# DeprecationWarning: Call to deprecated `similar_by_vector` (Method will be removed in 4.0.0, use self.wv.similar_by_vector() instead). [ipykernel_launcher.py:1]
# [('noisy data', 1.0),
#  ('using low variance', 0.9999990463256836),
#  ('lin cf wan', 0.9999977350234985),
#  ('normal activation patterns', 0.9999890327453613),
#  ('modified without retraining', 0.9999834299087524),
#  ('manually generated network', 0.9999814033508301),
#  ('intrusion detection wei', 0.9999558329582214),
#  ('map units instead', 0.9999547004699707),
#  ('whole data set', 0.999949038028717),
#  ('least discriminant eigenvectors', 0.999910831451416),
#  ('relative density calculation', 0.9998610615730286),
#  ('effective feature sets', 0.9998534321784973),
#  ('svs therefore samples', 0.9998259544372559),
#  ('algorithm classifies unbalanced', 0.9997761249542236),
#  ('contents lists available', 0.999754786491394),
#  ('child processes forked', 0.9996373653411865),
#  ('accuracy rate feature', 0.9995810985565186),
#  ('thus filter methods', 0.9993849396705627),
#  ('abnormal traces participate', 0.9993751049041748),
#  ('science beijing university', 0.9993201494216919),
#  ('new fsvm method', 0.9993049502372742),
#  ('unit nevertheless detecting', 0.9989166259765625),
#  ('sombased classifier described', 0.9988770484924316),
#  ('trans neural netw', 0.998752236366272),
#  ('systems ids necessary', 0.9985308051109314),
#  ('x using classcenter', 0.9978543519973755),
#  ('secured transactions london', 0.9978488087654114),
#  ('th near st', 0.9978057742118835),
#  ('abstract since svm', 0.9976170659065247),
#  ('pattern loses local', 0.9973955750465393),
#  ('square support vector', 0.9973941445350647),
#  ('algorithm takes account', 0.997288703918457),
#  ('malware classification using', 0.9972475171089172),
#  ('nids often fails', 0.9970301985740662),
#  ('learning method based', 0.996840238571167),
#  ('api call graph', 0.9966328144073486),
#  ('input data samples', 0.9965100884437561),
#  ('normal connections similarly', 0.9963964223861694),
#  ('center keywords support', 0.9963653087615967),
#  ('visualization strategy expert', 0.9963548183441162),
#  ('support vectors implements', 0.9963493347167969),
#  ('files false alarm', 0.995671272277832),
#  ('deep learning nature', 0.9954833984375),
#  ('hybrid intrusion detection', 0.995258629322052),
#  ('density factor ldf', 0.9950032234191895),
#  ('data space thus', 0.9949883222579956),
#  ('knowledge discovery problems', 0.994929313659668),
#  ('samples noise samples', 0.9948647618293762),
#  ('samples therefore using', 0.9947425127029419),
#  ('network continuously refines', 0.9945570230484009),
#  ('ids works similarly', 0.9945124983787537),
#  ('result index terms', 0.9940813183784485),
#  ('detect new attacks', 0.9940270781517029),
#  ('two first principal', 0.9935380220413208),
#  ('classifies unbalanced samples', 0.9934725761413574),
#  ('fuzzy membership considered', 0.993170976638794),
#  ('two ids design', 0.9931412935256958),
#  ('local density factor', 0.9928205013275146),
#  ('removing system call', 0.9927977323532104),
#  ('massive concurrent data', 0.9927256107330322),
#  ('selfstructuring confabulation network', 0.9927175045013428),
#  ('may cause false', 0.9926762580871582),
#  ('weight coefficients even', 0.9926522970199585),
#  ('deep convolutional neural', 0.9922999739646912),
#  ('training samples therefore', 0.9912452697753906),
#  ('whose closest prototype', 0.9904310703277588),
#  ('corresponding authors ying', 0.9902635216712952),
#  ('filtering feature selection', 0.9898916482925415),
#  ('years many machine', 0.9896864891052246),
#  ('relative position relation', 0.989393949508667),
#  ('ye q wu', 0.9891024231910706),
#  ('nn r x', 0.988972544670105),
#  ('given object unlike', 0.988594651222229),
#  ('vector machines based', 0.9883328676223755),
#  ('sets illustrate superior', 0.9861742258071899),
#  ('specific closeness thresholds', 0.985101580619812),
#  ('class separation case', 0.9846936464309692),
#  ('imbalanced classification ieee', 0.9842405319213867),
#  ('modern nids solutions', 0.9838026762008667),
#  ('new data instance', 0.9837956428527832),
#  ('membership function structure', 0.9835587739944458),
#  ('professor forrests conclusion', 0.9822111129760742),
#  ('system sequence numbered', 0.9818532466888428),
#  ('ther knowledge discovery', 0.9807415008544922),
#  ('rate respectively gauss', 0.9804882407188416),
#  ('recent years many', 0.9804805517196655),
#  ('detection rate decreases', 0.9798345565795898),
#  ('contains lprcp symbolic', 0.9790509939193726),
#  ('machines ieee trans', 0.9787029027938843),
#  ('three subsections feature', 0.9778039455413818),
#  ('wrapper methods usually', 0.9775489568710327),
#  ('training data eigenvalues', 0.9766475558280945),
#  ('x þ circles', 0.9766311645507812),
#  ('g deep learning', 0.975824773311615),
#  ('rate missing alarm', 0.9756573438644409),
#  ('feature selections derived', 0.9754930138587952),
#  ('short system sequences', 0.9754819869995117),
#  ('decreases gradually figure', 0.9752621650695801),
#  ('new mexico university', 0.9750182628631592),
#  ('relative local density', 0.974959135055542),
#  ('okayama japan email', 0.9739358425140381),
#  ('sequence pattern loses', 0.9739176630973816),
#  ('calls alternative data', 0.9739161133766174),
#  ('results specifically section', 0.973721981048584),
#  ('less experimental data', 0.9737216830253601),
#  ('second principal component', 0.9736592769622803),
#  ('system shows good', 0.9736043214797974),
#  ('vector machine int', 0.9731917381286621),
#  ('distancebased methods detect', 0.9729639887809753),
#  ('classifying system call', 0.9723137617111206),
#  ('selection methods although', 0.9718208909034729),
#  ('membership function according', 0.9716839790344238),
#  ('detection performance overhead', 0.9714601039886475),
#  ('words membership function', 0.971335768699646),
#  ('ndimensional data manifold', 0.971128523349762),
#  ('salaün g robust', 0.9709427356719971),
#  ('android malware detection', 0.9709053635597229),
#  ('proposed fuzzy support', 0.9707242250442505),
#  ('learning classical models', 0.9707120656967163),
#  ('author contributions conceptualization', 0.9705561399459839),
#  ('sv fuzzy support', 0.9704384207725525),
#  ('minimum hyperspheres based', 0.9703110456466675),
#  ('fuzzy support vector', 0.9698981046676636),
#  ('system ksii trans', 0.9694496393203735),
#  ('project administration lc', 0.969192624092102),
#  ('given greater weight', 0.9681816101074219),
#  ('improved neighborhood search', 0.9677425026893616),
#  ('inherent representation problems', 0.9674364328384399),
#  ('minimum hypersphere radius', 0.9671430587768555),
#  ('tcp connection attempts', 0.9666876792907715),
#  ('detection systems arxiv', 0.9666122198104858),
#  ('cluster center keywords', 0.9659131765365601),
#  ('way nslkdd constitutes', 0.9649114012718201),
#  ('intelligent services received', 0.9643950462341309),
#  ('method using eigenvectors', 0.9642185568809509),
#  ('detection performance worse', 0.9639678001403809),
#  ('massive data traffics', 0.963718056678772),
#  ('dataset follow different', 0.9635945558547974),
#  ('avoid using low', 0.9634753465652466),
#  ('intelligent telecommunication software', 0.9630283117294312),
#  ('least square support', 0.9623979330062866),
#  ('learning deep learning', 0.9619928002357483),
#  ('koutsoukos x optimal', 0.9604048728942871),
#  ('neighborhood three kinds', 0.9597939848899841),
#  ('firewalllike systems capable', 0.9597771167755127),
#  ('network anomalies respectively', 0.958632230758667),
#  ('local files false', 0.9578831195831299),
#  ('function neural comput', 0.9575451016426086),
#  ('using kernel density', 0.9575423002243042),
#  ('nanda p tan', 0.9575390815734863),
#  ('host system call', 0.9565170407295227),
#  ('rate decreases gradually', 0.9558867812156677),
#  ('batch kmeans algorithm', 0.9555908441543579),
#  ('system artificial intelligence', 0.954107940196991),
#  ('short system call', 0.9540719985961914),
#  ('sendmail algorithm detection', 0.9539722204208374),
#  ('decades many outlier', 0.9539008736610413),
#  ('database similarly outdated', 0.953785240650177),
#  ('relatively low detection', 0.9532508850097656),
#  ('host data acm', 0.9527024030685425),
#  ('support vector data', 0.9524515271186829),
#  ('fundamental research funds', 0.9511843919754028),
#  ('best matching unit', 0.9507958292961121),
#  ('classification task problems', 0.9504461288452148),
#  ('intrusion detection approach', 0.94913250207901),
#  ('terms ddos attack', 0.947473406791687),
#  ('data set consists', 0.9467275738716125),
#  ('selection methods contribute', 0.946252703666687),
#  ('proposed rdos including', 0.9456537365913391),
#  ('detected anomaly behavior', 0.9455784559249878),
#  ('potentially dangerous incoming', 0.9450922012329102),
#  ('trans fuzzy syst', 0.9444990754127502),
#  ('robust kernelbased outlier', 0.9442970156669617),
#  ('activation probabilities pi', 0.9441555738449097),
#  ('hypersphere represent noises', 0.9439547061920166),
#  ('false alarm probability', 0.9433841109275818),
#  ('routine signature update', 0.9423313140869141),
#  ('symbolic link intrusions', 0.9409694671630859),
#  ('data set includes', 0.9408324360847473),
#  ('natural language processing', 0.9408067464828491),
#  ('detection method using', 0.9404491782188416),
#  ('set activation probability', 0.9401581883430481),
#  ('sim ilar work', 0.9396408796310425),
#  ('new fuzzy support', 0.9396154880523682),
#  ('decreasing variance order', 0.9369773864746094),
#  ('detect local outliers', 0.9368370175361633),
#  ('graph embeddings soft', 0.9366194009780884),
#  ('alarm rate start', 0.9366112351417542),
#  ('locally reachable neighborhood', 0.9362008571624756),
#  ('incoming traffic however', 0.9358519911766052),
#  ('common protection approaches', 0.9357222318649292),
#  ('fuzzy support machine', 0.9354557991027832),
#  ('japan email zhenyuistosakauacjp', 0.9353029727935791),
#  ('usually less computational', 0.9347110390663147),
#  ('daily life network', 0.9345713257789612),
#  ('feature space therefore', 0.9339785575866699),
#  ('methods usually outperform', 0.9331867694854736),
#  ('negative error rate', 0.9327561259269714),
#  ('alarm rate nbayes', 0.9327107667922974),
#  ('malware analysis using', 0.9316558837890625),
#  ('design membership functions', 0.9314297437667847),
#  ('attacks whose signature', 0.9311956167221069),
#  ('statistical learning data', 0.9294206500053406),
#  ('two different classes', 0.9270058870315552),
#  ('weighted density estimate', 0.9266154170036316),
#  ('priori logarithmic activation', 0.925653338432312),
#  ('similar data instances', 0.9256226420402527),
#  ('convex sets far', 0.925396203994751),
#  ('anomaly detection thus', 0.9248255491256714),
#  ('complex features allows', 0.9241759777069092),
#  ('namely anomalybased ids', 0.9230035543441772),
#  ('two different parameters', 0.9202606678009033),
#  ('random forest support', 0.9201355576515198),
#  ('given less weight', 0.9188364744186401),
#  ('least squares support', 0.9186722636222839),
#  ('methods construct normal', 0.918560802936554),
#  ('high technology research', 0.9182180166244507),
#  ('vector machine needs', 0.9168758392333984),
#  ('noise samples noise', 0.916744589805603),
#  ('anomaly detection system', 0.915801465511322),
#  ('corresponding author yonghao', 0.9134851098060608),
#  ('nbayes uniqueness hybrid', 0.912161111831665),
#  ('characterize normal patterns', 0.912131667137146),
#  ('function structure method', 0.9094772338867188),
#  ('data processing data', 0.908968985080719),
#  ('technology osaka university', 0.9085150361061096),
#  ('enable remote users', 0.9084477424621582),
#  ('data mining nslkdd', 0.90825355052948),
#  ('process multiple gpus', 0.9056156277656555),
#  ('minimum volume hypersphere', 0.9037148356437683),
#  ('ids concerns expressed', 0.903144896030426),
#  ('method pay attention', 0.9027951955795288),
#  ('detection rate false', 0.9012809991836548),
#  ('ids selforganizing maps', 0.8996925950050354),
#  ('optimal level table', 0.8995786309242249),
#  ('incremental learning sheraz', 0.8988913297653198),
#  ('classification hyperplane lies', 0.8984400629997253),
#  ('new training sample', 0.898237407207489),
#  ('performance worse therefore', 0.8954732418060303),
#  ('intrusion detection approaches', 0.894831657409668),
#  ('learning dual convolutional', 0.8934664726257324),
#  ('goal behind using', 0.8907284140586853),
#  ('b communications engineering', 0.8907104134559631),
#  ('modified local files', 0.8898721933364868),
#  ('first eigenvectors comprise', 0.8898569345474243),
#  ('distancebased algorithm however', 0.8889104127883911),
#  ('classification hyperplane figure', 0.8887684345245361),
#  ('novel intrusion detection', 0.8884057998657227),
#  ('detection system ksii', 0.8874894976615906),
#  ('kernelbased outlier factor', 0.8874312043190002),
#  ('experimental performance comparison', 0.8864505290985107),
#  ('principal components ui', 0.8863368034362793),
#  ('learning autoencoder random', 0.8858188986778259),
#  ('normal traffic different', 0.8850998878479004),
#  ('deep learning approach', 0.8822503685951233),
#  ('network intrusion detection', 0.8804517984390259),
#  ('b tang heeleuriedu', 0.8795088529586792),
#  ('recent decades many', 0.8789136409759521),
#  ('stateoftheart outlier detection', 0.8782994747161865),
#  ('density distribution estimation', 0.876928448677063),
#  ('fsvm assigns different', 0.8764653205871582),
#  ('test result implies', 0.876389741897583),
#  ('networks ksii trans', 0.8756564855575562),
#  ('given larger weight', 0.8748024106025696),
#  ('fuzzy twin support', 0.8729738593101501),
#  ('collaborative filtering int', 0.8719851970672607),
#  ('novel semisupervised learning', 0.8710511326789856),
#  ('dynamic android malware', 0.8706893920898438),
#  ('sequence matching compression', 0.8661014437675476),
#  ('recent ids reference', 0.8626453280448914),
#  ('traffic data set', 0.8625430464744568),
#  ('exploit detection arxiv', 0.8620948791503906),
#  ('method allows selecting', 0.8620697855949402),
#  ('systems usually characterize', 0.8613064289093018),
#  ('negative sample points', 0.8609789609909058),
#  ('contain lprcp attacks', 0.8604079484939575),
#  ('density estimation ethods', 0.8595685362815857),
#  ('shows good detection', 0.8593538403511047),
#  ('neighbors considered arrows', 0.8586602807044983),
#  ('important input space', 0.8563669919967651),
#  ('membership function inside', 0.8552538156509399),
#  ('machine learning field', 0.8544232249259949),
#  ('data sets ieee', 0.8523530960083008),
#  ('national natural science', 0.8520041704177856),
#  ('r lower fdr', 0.8510298728942871),
#  ('vision applications comput', 0.8464493155479431),
#  ('five algorithms figure', 0.8455113172531128),
#  ('newer attacks necessitates', 0.8450750708580017),
#  ('uses less resources', 0.8437841534614563),
#  ('detection systems soft', 0.8434840440750122),
#  ('ln detection rate', 0.8433964252471924),
#  ('uniform guiding principles', 0.8429234623908997),
#  ('reverse nearest neighbors', 0.841378927230835),
#  ('algorithms svm algorithm', 0.8409408330917358),
#  ('wenke lees conclusion', 0.8381383419036865),
#  ('detection rate respectively', 0.8379653096199036),
#  ('false alarm rate', 0.8329172134399414),
#  ('south china university', 0.8328838348388672),
#  ('threeway decision making', 0.8313784003257751),
#  ('kronecker delta vectors', 0.8285588026046753),
#  ('cases mapping function', 0.8283864855766296),
#  ('imbalance samples good', 0.8277904391288757),
#  ('method extracts user', 0.8275492787361145),
#  ('less resources based', 0.8240495920181274),
#  ('experimental results obtained', 0.8237948417663574),
#  ('methods detect outliers', 0.82332843542099),
#  ('manning cd advances', 0.8128679990768433),
#  ('network normal traffic', 0.8126124143600464),
#  ('data using support', 0.8118119835853577),
#  ('discriminative enough contain', 0.8083727955818176),
#  ('process identity pid', 0.8074146509170532),
#  ('selection methods reduce', 0.8059901595115662),
#  ('membership function must', 0.8059887290000916),
#  ('ms bridges ra', 0.8051284551620483),
#  ('data sets illustrate', 0.8029384613037109),
#  ('topsis evaluation factor', 0.8027945756912231),
#  ('real anomaly detection', 0.8008518218994141),
#  ('lately several variations', 0.7998077869415283),
#  ('classifier thus filter', 0.7991065382957458),
#  ('data capturing valuable', 0.7990454435348511),
#  ('information technologists conference', 0.7953743934631348),
#  ('privacy preservation although', 0.7930698394775391),
#  ('st neighbor indicates', 0.7925781607627869),
#  ('pca filtering feature', 0.7921035289764404),
#  ('features allows discovering', 0.7909987568855286),
#  ('affinity among samples', 0.7902650237083435),
#  ('anomaly detection systems', 0.7898030281066895),
#  ('therefore membership functions', 0.7876284718513489),
#  ('fuzzy log intell', 0.7859539985656738),
#  ('usa b department', 0.7859513759613037),
#  ('negative samples r', 0.7859495282173157),
#  ('hybrid markov method', 0.7804227471351624),
#  ('either raw data', 0.779295802116394),
#  ('data collection system', 0.7774159908294678),
#  ('prior activation probabilities', 0.7767755389213562),
#  ('corresponding bmu whenever', 0.7763909101486206),
#  ('selection procedures sections', 0.7750225067138672),
#  ('nonlocal neural networks', 0.7748434543609619),
#  ('artificial neural network', 0.7747564315795898),
#  ('lc funding acquisition', 0.7724424004554749),
#  ('cofbased outlier detection', 0.7707676887512207),
#  ('trace detection using', 0.7679355144500732),
#  ('robust local outlier', 0.7649896740913391),
#  ('respectively appl sci', 0.7628723978996277),
#  ('current link bandwidths', 0.7623593807220459),
#  ('systems sufficiently accurate', 0.7614065408706665),
#  ('attackers include firewalllike', 0.7579149603843689),
#  ('function kxi x', 0.7573667764663696),
#  ('comprehensive experimental study', 0.7513927221298218),
#  ('author email addresses', 0.7481852769851685),
#  ('better detection rate', 0.7453210353851318),
#  ('time appl sci', 0.7450894117355347),
#  ('selection algorithm ieee', 0.7443287968635559),
#  ('misreading legitimate traffic', 0.7417081594467163),
#  ('detection clouds robotic', 0.741166353225708),
#  ('learning theory makes', 0.7400451302528381),
#  ('intrusion detection intrusion', 0.7382710576057434),
#  ('risk minimization principle', 0.7367721199989319),
#  ('using api call', 0.7361566424369812),
#  ('too few labeled data', 0.7351809144020081),
#  ('security labknowledge discovery', 0.733497679233551),
#  ('second map dimensions', 0.7316171526908875),
#  ('samples approaches infinity', 0.7314376831054688),
#  ('multiple sources therefore', 0.7312967777252197),
#  ('low detection rate', 0.7271976470947266),
#  ('latest attack patterns', 0.7257003784179688),
#  ('sequencesbased methods need', 0.7237793803215027),
#  ('thesis east carolina', 0.7232633829116821),
#  ('sciencedirect journal homepage', 0.7216233015060425),
#  ('storage appl sci', 0.7175557613372803),
#  ('feature selection algorithm', 0.7164493799209595),
#  ('deep neural networks', 0.7154718637466431),
#  ('membership functions figure', 0.7138875722885132),
#  ('contain abnormal samples', 0.7130669355392456),
#  ('ieee trans neural', 0.7111151814460754),
#  ('efficient convolutional neural', 0.7081504464149475),
#  ('probability distributions however', 0.6931963562965393),
#  ('feature selection methods', 0.6930050253868103),
#  ('local system data', 0.6929125785827637),
#  ('rapidly increasing ubiquitous', 0.6892744302749634),
#  ('machines using sequential', 0.686319887638092),
#  ('kmeans detection method', 0.6858983039855957),
#  ('acknowledgments system call', 0.685543417930603),
#  ('soft science foundation', 0.6842427849769592),
#  ('hyperplane given p', 0.6810057163238525),
#  ('boundary vector set', 0.6782866716384888),
#  ('ensemble learning based', 0.6779487729072571),
#  ('network security foundation', 0.6729353666305542),
#  ('discriminative eigenvectors thus', 0.6715923547744751),
#  ('neural network based', 0.6677671670913696),
#  ('space consuming due', 0.6652427911758423),
#  ('new training dataset', 0.6648711562156677),
#  ('lan abnormal traces', 0.65920090675354),
#  ('probabilistic selforganizing maps', 0.6585432291030884),
#  ('abstractwith information technology', 0.6570475101470947),
#  ('accuracy bloom filter', 0.6560088992118835),
#  ('average detection rate', 0.6517338752746582),
#  ('east london south', 0.6514418125152588),
#  ('density score termed', 0.6488853693008423),
#  ('yh fuzzy support', 0.6475343704223633),
#  ('learning approach via', 0.6468149423599243),
#  ('multilabel classification pattern', 0.6466967463493347),
#  ('whole fuzzy algorithm', 0.6446449160575867),
#  ('formal analysis wl', 0.6414817571640015),
#  ('activation probability similarly', 0.6407976150512695),
#  ('system call patterns', 0.6370639801025391),
#  ('forest rf models', 0.6365358233451843),
#  ('many ther knowledge', 0.6349997520446777),
#  ('good detection performance', 0.6336610317230225),
#  ('sd detecting anomalies', 0.6305625438690186),
#  ('good noise tolerance', 0.627954363822937),
#  ('obtain root directory', 0.6255878210067749),
#  ('classify system calls', 0.6223909854888916),
#  ('root directory information', 0.616435170173645),
#  ('similarly outdated databases', 0.6103137731552124),
#  ('let x arn', 0.6043810844421387),
#  ('membership design method', 0.6016862392425537),
#  ('case thus anomalies', 0.600628137588501),
#  ('training data samples', 0.5976045727729797),
#  ('processing society workshop', 0.5940427780151367),
#  ('ensuring sufficient data', 0.5920706987380981),
#  ('access article distributed', 0.5905054807662964),
#  ('different detection approaches', 0.5903615951538086),
#  ('high performance among', 0.5884346961975098),
#  ('contentbased features since', 0.587554395198822),
#  ('processing whenever new', 0.586694061756134),
#  ('different probability distributions', 0.5843321084976196),
#  ('neural netw learn', 0.5838422179222107),
#  ('corresponding patterns associated', 0.5833780765533447),
#  ('machine learning techniques', 0.5815285444259644),
#  ('last years different', 0.5813361406326294),
#  ('detection intrusion detection', 0.5788478851318359),
#  ('highest lof scores', 0.5756810307502747),
#  ('weighted support vector', 0.5755115151405334),
#  ('radius r ϕx', 0.5716553330421448),
#  ('funding acquisition wl', 0.5698779225349426),
#  ('corresponding time windows', 0.5683007836341858),
#  ('obtains excellent results', 0.5661916732788086),
#  ('secure systems master', 0.5653456449508667),
#  ('society workshop madison', 0.5633469820022583),
#  ('lower computation cost', 0.563091516494751),
#  ('strategy expert syst', 0.5602187514305115),
#  ('current version october', 0.5548866987228394),
#  ('input data instance', 0.5525546073913574),
#  ('file lists pairs', 0.552466630935669),
#  ('containing enough support', 0.5507049560546875),
#  ('missing rate indicates', 0.5494634509086609),
#  ('attack detection accuracy', 0.5454006195068359),
#  ('detection using deep', 0.5417698621749878),
#  ('matching method respectively', 0.5357627868652344),
#  ('traditional fuzzy support', 0.5349541902542114),
#  ('outlier detection approaches', 0.5289000272750854),
#  ('outlier detection method', 0.5257705450057983),
#  ('trans dependable secur', 0.5247582793235779),
#  ('index terms intrusion', 0.5180410146713257),
#  ('bh artificial neural', 0.5163679122924805),
#  ('factor index terms', 0.5156829953193665),
#  ('anomalybased methods construct', 0.5155265927314758),
#  ('function must consider', 0.512098491191864),
#  ('stored ones however', 0.5100736021995544),
#  ('experimental results specifically', 0.5094187259674072),
#  ('leveraging host data', 0.5031699538230896),
#  ('pacific services computing', 0.5028442740440369),
#  ('roc curve alone', 0.49936506152153015),
#  ('exposed significant amounts', 0.49867501854896545),
#  ('administration lc funding', 0.4982910454273224),
#  ('malware detection based', 0.49817997217178345),
#  ('input data space', 0.4974310100078583),
#  ('analysis using probabilistic', 0.49639448523521423),
#  ('previous work based', 0.4951770007610321),
#  ('assigns different weight', 0.4938110113143921),
#  ('processing comput sci', 0.49369174242019653),
#  ('particle swarm optimisation', 0.491998553276062),
#  ('volume hypersphere containing', 0.4896785318851471),
#  ('ieee signal processing', 0.4892037808895111),
#  ('system call databases', 0.4868813753128052),
#  ('euclidean distance ξi', 0.4860360026359558),
#  ('mixture model gmm', 0.4856453835964203),
#  ('hostbased intrusion detection', 0.4827163517475128),
#  ('different data instances', 0.4815470576286316),
#  ('support vector proposed', 0.47905394434928894),
#  ('intrusion detection system', 0.475884348154068),
#  ('keywordsnetwork intrusion detection', 0.4754357635974884),
#  ('deep learning autoencoder', 0.4748290777206421),
#  ('js pattern recognition', 0.4727536737918854),
#  ('short sequence becomes', 0.4708605110645294),
#  ('algorithm increases successively', 0.46878373622894287),
#  ('authors licensee mdpi', 0.46851587295532227),
#  ('data unit consists', 0.46402785181999207),
#  ('rough sets inf', 0.46368902921676636),
#  ('cluster centers selection', 0.46299290657043457),
#  ('subsequently feature space', 0.4618266522884369),
#  ('wrapper approach implements', 0.4609776437282562),
#  ('xu fuzzy support', 0.4579852223396301),
#  ('component analysis pca', 0.4566192924976349),
#  ('problems outlier detection', 0.45365628600120544),
#  ('relevant dataset information', 0.4504316449165344),
#  ('ids reference works', 0.4498921036720276),
#  ('unsupervised learning algorithms', 0.4491085708141327),
#  ('may become support', 0.4475340247154236),
#  ('boundary vectors containing', 0.4436992108821869),
#  ('log ð xi', 0.4409503638744354),
#  ('system call sequence', 0.43909981846809387),
#  ('missing rate table', 0.4377833306789398),
#  ('words signaturebased ids', 0.4342937171459198),
#  ('sually called outliers', 0.43061012029647827),
#  ('termed relative densitybased', 0.42980387806892395),
#  ('although pca sorts', 0.4298034608364105),
#  ('vector data description', 0.42896056175231934),
#  ('national high technology', 0.4281424283981323),
#  ('vector machine fsvm', 0.42493942379951477),
#  ('gaussian mixture model', 0.42412036657333374),
#  ('usually outperform filter', 0.4207417070865631),
#  ('statistical learning theory', 0.41863057017326355),
#  ('main goal behind', 0.4169864356517792),
#  ('detection systems application', 0.4158884584903717),
#  ('combining heterogeneous anomaly', 0.4156114459037781),
#  ('method effectively distinguishes', 0.41552844643592834),
#  ('gravitational search algorithm', 0.4106897711753845),
#  ('process system call', 0.4102137088775635),
#  ('intrusion detection clouds', 0.4093526601791382),
#  ('investigating transition characteristics', 0.4090789556503296),
#  ('eigenvectors thus reducing', 0.40834373235702515),
#  ('detected abnormal traces', 0.40810564160346985),
#  ('detection using api', 0.40752148628234863),
#  ('database construction stage', 0.4074942171573639),
#  ('algorithm ieee trans', 0.4070020318031311),
#  ('given input vector', 0.40546396374702454),
#  ('boundary vector containing', 0.4042968153953552),
#  ('class imbalance learning', 0.40338945388793945),
#  ('removal probabilistic selforganizing', 0.4023115634918213),
#  ('vector machine svm', 0.4021264612674713),
#  ('learning theory statistical', 0.3992011845111847),
#  ('call sequences support', 0.3991592526435852),
#  ('article history received', 0.3981243968009949),
#  ('systems master thesis', 0.39745450019836426),
#  ('data collection systems', 0.3966250717639923),
#  ('system calls therefore', 0.3941643536090851),
#  ('high performance computing', 0.39415231347084045),
#  ('following quadratic programming', 0.3937499523162842),
#  ('description ϕ rn', 0.3931180536746979),
#  ('rights reserved advances', 0.39214450120925903),
#  ('creative commons attribution', 0.39144569635391235),
#  ('fuzzy membership functions', 0.39013275504112244),
#  ('intrusion detection systems', 0.3892039358615875),
#  ('analysis methodology aimed', 0.38880157470703125),
#  ('prediction author contributions', 0.3871613144874573),
#  ('accurate prediction author', 0.38335925340652466),
#  ('enough contain redundant', 0.38209015130996704),
#  ('different machine learning', 0.38074347376823425),
#  ('nonlinear cases mapping', 0.37802523374557495),
#  ('gets better classification', 0.3763856291770935),
#  ('public security abstract', 0.37610653042793274),
#  ('colombia b communications', 0.375351220369339),
#  ('network security labknowledge', 0.3731607496738434),
#  ('real campus network', 0.3728913366794586),
#  ('cf wan sd', 0.3710848093032837),
#  ('algorithm effectively distinguishes', 0.3691402077674866),
#  ('initialization method implies', 0.36614203453063965),
#  ('missing alarm rate', 0.36375415325164795),
#  ('hidden markov model', 0.36342278122901917),
#  ('fast incremental learning', 0.36177608370780945),
#  ('using system calls', 0.3561723232269287),
#  ('lowest comprehensive detection', 0.35577335953712463),
#  ('virtual machines using', 0.353851854801178),
#  ('university osaka japan', 0.3536733388900757),
#  ('effective appl sci', 0.3532458245754242),
#  ('vector machine svdd', 0.3522630035877228),
#  ('probability density function', 0.3519846498966217),
#  ('high dimensional ata', 0.3491648733615875),
#  ('matching unit bmu', 0.34915852546691895),
#  ('guangzhou peoples livelihood', 0.3469899892807007),
#  ('present known attacks', 0.34568116068840027),
#  ('circled processor trace', 0.3433448076248169),
#  ('αðtþ diminishes following', 0.343134343624115),
#  ('four algorithms treat', 0.3425319790840149),
#  ('science government usiness', 0.33923253417015076),
#  ('dynamic data', 0.3390776813030243),
#  ('map dimensions respectively', 0.33842766284942627),
#  ('kmeans algorithm using', 0.33838212490081787),
#  ('different data units', 0.3310530185699463),
#  ('ipma sequence matching', 0.3272857069969177),
#  ('naive bayesian method', 0.32579687237739563),
#  ('mining knowl based', 0.3219657242298126),
#  ('trace file lists', 0.32049688696861267),
#  ('feature selection method', 0.3196737766265869),
#  ('although wrapper methods', 0.3188672363758087),
#  ('ensemble learning deep', 0.31541645526885986),
#  ('network based intrusion', 0.31535348296165466),
#  ('twin support vector', 0.315314918756485),
#  ('information system security', 0.3149852156639099),
#  ('local densitybased approach', 0.31497466564178467),
#  ('two cluster centers', 0.3133569657802582),
#  ('support vector machine', 0.3120747208595276),
#  ('using sequential mining', 0.30692732334136963),
#  ('communication soft science', 0.3069203197956085),
#  ('capturing valuable information', 0.3060106039047241),
#  ('training samples onto', 0.3022775948047638),
#  ('methods need constructing', 0.30200135707855225),
#  ('x nanda p', 0.2987300455570221),
#  ('make sendmail attach', 0.2961553633213043),
#  ('negative predictions keywordsnetwork', 0.2960352897644043),
#  ('machine host system', 0.2959810793399811),
#  ('deficient signatures may', 0.2944837212562561),
#  ('image classification int', 0.29120972752571106),
#  ('ln normal traces', 0.2886504530906677),
#  ('covariance matrix computed', 0.28238025307655334),
#  ('engineering south china', 0.2792912721633911),
#  ('feature space modelling', 0.2787128686904907),
#  ('following equation algorithm', 0.2733042538166046),
#  ('many machine learning', 0.2710639238357544),
#  ('central limit theorem', 0.2702409625053406),
#  ('membership definition based', 0.26602187752723694),
#  ('false positive rate', 0.26419705152511597),
#  ('principal components account', 0.2628242075443268),
#  ('hand different data', 0.26162189245224),
#  ('researchers proposed fuzzy', 0.2595016658306122),
#  ('data collection process', 0.25241345167160034),
#  ('malware detection using', 0.2518244683742523),
#  ('overfitting problem increasing', 0.2504410445690155),
#  ('input data along', 0.24741940200328827),
#  ('privacy analytics new', 0.24631503224372864),
#  ('abnormal traces including', 0.24566352367401123),
#  ('mach learn cybern', 0.24456533789634705),
#  ('dimensional problems makes', 0.24329392611980438),
#  ('false alarm rates', 0.24311873316764832),
#  ('sequence becomes longer', 0.2423880696296692),
#  ('output map moreover', 0.24192386865615845),
#  ('idering underlying patterns', 0.24170543253421783),
#  ('consider reverse nearest', 0.2395089864730835),
#  ('new tool data', 0.239146888256073),
#  ('training samples contain', 0.2386595904827118),
#  ('hybrid methods filter', 0.23790761828422546),
#  ('q luley r', 0.23770982027053833),
#  ('machine feature selection', 0.2340160608291626),
#  ('local kernel density', 0.23374107480049133),
#  ('years different intrusion', 0.23349952697753906),
#  ('pcafdr feature selection', 0.23200026154518127),
#  ('classification ieee trans', 0.2294061779975891),
#  ('nearby support vectors', 0.22482821345329285),
#  ('different samples inside', 0.22342661023139954),
#  ('solving quadratic programming', 0.22285500168800354),
#  ('supervised learningmethods need', 0.22099953889846802),
#  ('probabilistic rough sets', 0.21916860342025757),
#  ('proposed feature selection', 0.21783897280693054),
#  ('detect ddos attack', 0.217108815908432),
#  ('vector machines ieee', 0.21611401438713074),
#  ('intel circled processor', 0.2143670618534088),
#  ('th wrapper approach', 0.21313568949699402),
#  ('function appl sci', 0.21257176995277405),
#  ('negative samples xi', 0.20807108283042908),
#  ('department citic university', 0.206793874502182),
#  ('using graphbased representations', 0.20583361387252808),
#  ('information security ids', 0.2029041349887848),
#  ('known patterns associated', 0.2017049491405487),
#  ('systemcalls analysis methodology', 0.20044267177581787),
#  ('system call datasets', 0.19919908046722412),
#  ('support vectors lie', 0.19533446431159973),
#  ('membership function appl', 0.1945558488368988),
#  ('filterbased feature selection', 0.19165819883346558),
#  ('correct experimental conclusions', 0.19022062420845032),
#  ('new wtxa w', 0.19008862972259521),
#  ('using text mining', 0.1890910267829895),
#  ('ubiquitous networking technology', 0.18706387281417847),
#  ('learningmethods need large', 0.18437039852142334),
#  ('neighborhood different density', 0.18309634923934937),
#  ('poses interesting problems', 0.17850056290626526),
#  ('new fuzzy twin', 0.17713961005210876),
#  ('implemented intrusion detection', 0.1769886314868927),
#  ('detection systems using', 0.1763337254524231),
#  ('increasing ubiquitous networking', 0.17617124319076538),
#  ('redundant data', 0.1754586100578308),
#  ('priori activation probabilities', 0.17243078351020813),
#  ('effective relative density', 0.1688092052936554),
#  ('g bharat r', 0.16860568523406982),
#  ('short system sequence', 0.168229341506958),
#  ('shows good performance', 0.1673908233642578),
#  ('many false positives', 0.16422733664512634),
#  ('lprcp symbolic link', 0.16383200883865356),
#  ('kernel density estimation', 0.1624758541584015),
#  ('support vectors svs', 0.16172581911087036),
#  ('windows based computers', 0.15857765078544617),
#  ('data packets ids', 0.15806537866592407),
#  ('sequences support vector', 0.15675032138824463),
#  ('system call traces', 0.1559685468673706),
#  ('via ensemble learning', 0.151687353849411),
#  ('outlier score rdos', 0.1501322090625763),
#  ('classification algorithm based', 0.1483219563961029),
#  ('xi therefore membership', 0.14787432551383972),
#  ('illustrate superior performance', 0.1453763246536255),
#  ('five algorithms due', 0.14449721574783325),
#  ('become support vectors', 0.14364469051361084),
#  ('ð xi x', 0.13786622881889343),
#  ('second principal components', 0.13735082745552063),
#  ('error penalty factor', 0.13565269112586975),
#  ('data contains sunsendmailcp', 0.13390666246414185),
#  ('omlin cw evaluating', 0.13358533382415771),
#  ('detection system nids', 0.13150814175605774),
#  ('machine learning based', 0.13120511174201965),
#  ('usually characterize normal', 0.1270342767238617),
#  ('nearest neighbor distance', 0.12176638841629028),
#  ('ak android malware', 0.12092515826225281),
#  ('robust ensemble method', 0.1191413402557373),
#  ('cluster center zhang', 0.1184130311012268),
#  ('construction stage normal', 0.11783117055892944),
#  ('input data respectively', 0.11525225639343262),
#  ('campus network log', 0.11518242955207825),
#  ('approaches infinity unfortunately', 0.11496046185493469),
#  ('performance evaluation formula', 0.11163276433944702),
#  ('discovery problems outlier', 0.11074480414390564),
#  ('internet inf syst', 0.1099114716053009),
#  ('systems using contiguous', 0.10914981365203857),
#  ('practical engineering applications', 0.09825015068054199),
#  ('input space properties', 0.09574264287948608),
#  ('expensive wrapper methods', 0.09507143497467041),
#  ('membership function design', 0.09351193904876709),
#  ('methods focus primarily', 0.09217175841331482),
#  ('samples training samples', 0.0917513370513916),
#  ('ieee internet things', 0.0915575623512268),
#  ('digital object identifier', 0.0848778486251831),
#  ('solution topsis evaluation', 0.0776790976524353),
#  ('maps psom aim', 0.07637381553649902),
#  ('lowest detection rate', 0.0763407051563263),
#  ('highdimensional space assume', 0.06875094771385193),
#  ('lnew therefore membership', 0.06849217414855957),
#  ('larger weight coefficients', 0.06192517280578613),
#  ('cvpr salt lake', 0.06171521544456482),
#  ('lower fdr values', 0.05594682693481445),
#  ('weight coefficient compared', 0.054448843002319336),
#  ('training sample set', 0.05405771732330322),
#  ('usa available online', 0.05127894878387451),
#  ('structural risk minimization', 0.05124899744987488),
#  ('artificial intelligence techniques', 0.0467204749584198),
#  ('operation system kernel', 0.046584248542785645),
#  ('springer international publishing', 0.04617953300476074),
#  ('classification hyperplane obtained', 0.04204481840133667),
#  ('sample set contains', 0.04168975353240967),
#  ('high appl sci', 0.04137420654296875),
#  ('abnormal trace detection', 0.03999990224838257),
#  ('ent local patterns', 0.038723111152648926),
#  ('using classcenter vectors', 0.02253621816635132),
#  ('online network intrusion', 0.02039209008216858),
#  ('density estimation kde', 0.01992356777191162),
#  ('training set activation', 0.016266554594039917),
#  ('imbalance learning neural', 0.012002140283584595),
#  ('normal traffic finally', 0.011576324701309204),
#  ('commonly used traffic', 0.004547059535980225),
#  ('include firewalllike systems', 0.0036293864250183105),
#  ('pandit predefined workflow', 0.0034809410572052),
#  ('effective exploit detection', 0.0029570460319519043),
#  ('multiobjective particle swarm', 0.0029415786266326904),
#  ('intrusions enable remote', 0.002713620662689209),
#  ('detection fraudulent transactions', -0.0027748942375183105),
#  ('learning techniques applied', -0.007476925849914551),
#  ('addition using complex', -0.007577568292617798),
#  ('distances among objects', -0.01197516918182373),
#  ('maintained high however', -0.013003319501876831),
#  ('covariance matrix σ', -0.013213783502578735),
#  ('system calls alternative', -0.015414595603942871),
#  ('insufficient data svmbased', -0.016799122095108032),
#  ('membership function outside', -0.019411444664001465),
#  ('motivation behind using', -0.021882951259613037),
#  ('satisfactory results therefore', -0.023083537817001343),
#  ('anomalybased systems sufficiently', -0.02725180983543396),
#  ('membership function neural', -0.027548134326934814),
#  ('lowest false alarm', -0.029031723737716675),
#  ('worst comprehensive detection', -0.030248254537582397),
#  ('concurrent data streams', -0.03187131881713867),
#  ('attack patterns meanwhile', -0.033136069774627686),
#  ('different weight coefficients', -0.03501695394515991),
#  ('nids ensemble learning', -0.037393808364868164),
#  ('support vector machines', -0.03819751739501953),
#  ('recognition method using', -0.04230496287345886),
#  ('sufficient data parameters', -0.04409012198448181),
#  ('quadratic programming problem', -0.044502705335617065),
#  ('function design based', -0.04530775547027588),
#  ('ddos detection method', -0.04616779088973999),
#  ('representation problems due', -0.04891979694366455),
#  ('discriminant ratio fdr', -0.05188879370689392),
#  ('repeatedly sending similar', -0.05490341782569885),
#  ('specific input space', -0.05891457200050354),
#  ('learning ml techniques', -0.06114080548286438),
#  ('kernel function matrix', -0.06175166368484497),
#  ('autoencoder random forest', -0.0657687783241272),
#  ('approaches thus contributing', -0.06602746248245239),
#  ('machine svdd system', -0.06626424193382263),
#  ('random forest rf', -0.06828257441520691),
#  ('cloud computing infrastructures', -0.07007631659507751),
#  ('compare observed behaviours', -0.0702548623085022),
#  ('test environment however', -0.07495644688606262),
#  ('coefficients even though', -0.07846659421920776),
#  ('appropriate weight coefficients', -0.07856431603431702),
#  ('squared errors sse', -0.07883667945861816),
#  ('order first eigenvectors', -0.0794893205165863),
#  ('classification using bayesian', -0.08013549447059631),
#  ('user behavior patterns', -0.08025872707366943),
#  ('computer science beijing', -0.0809415876865387),
#  ('machine needs large', -0.08378833532333374),
#  ('ethods detect outliers', -0.08489656448364258),
#  ('selection algorithm yonghao', -0.08529242873191833),
#  ('data samples training', -0.08629831671714783),
#  ('comprehensive detection formula', -0.08823776245117188),
#  ('valid sample point', -0.09234249591827393),
#  ('intersection appl sci', -0.09524521231651306),
#  ('negative appl sci', -0.0956655740737915),
#  ('issues visvis assuring', -0.09588971734046936),
#  ('imbalanced data', -0.09622040390968323),
#  ('classification hyperplane equal', -0.09750744700431824),
#  ('memory occupation searching', -0.098072350025177),
#  ('b detecting intrusions', -0.09853777289390564),
#  ('intrusion prediction systems', -0.09855762124061584),
#  ('detection systems ids', -0.10089221596717834),
#  ('two separate cases', -0.10105237364768982),
#  ('exposed sensitive information', -0.1018049418926239),
#  ('sample vector x', -0.10192492604255676),
#  ('lc project administration', -0.1028633713722229),
#  ('rate missing rate', -0.10370227694511414),
#  ('wu q bishop', -0.10810679197311401),
#  ('methods reduce redundancy', -0.11024034023284912),
#  ('rate false alarm', -0.1137860119342804),
#  ('system uses less', -0.11451122164726257),
#  ('new fsvm algorithm', -0.1157548725605011),
#  ('general guidelines traditional', -0.11682751774787903),
#  ('synthetic data sets', -0.11823907494544983),
#  ('subsections feature filtering', -0.11878103017807007),
#  ('patterns ieee trans', -0.1212620735168457),
#  ('china corresponding authors', -0.12150359153747559),
#  ('ideal solution topsis', -0.1227039098739624),
#  ('sccp intrusions enable', -0.12422406673431396),
#  ('weighted kmeans detection', -0.12727752327919006),
#  ('bloomfilterbased method shows', -0.12751898169517517),
#  ('virtual machine feature', -0.12954163551330566),
#  ('opcodes future gener', -0.1322680413722992),
#  ('new training samples', -0.13262000679969788),
#  ('enhanced network intrusion', -0.13540619611740112),
#  ('effective android malware', -0.13791868090629578),
#  ('email addresses botanghofstraedu', -0.13958624005317688),
#  ('vincent ms bridges', -0.14153146743774414),
#  ('fuzzy membership function', -0.14243799448013306),
#  ('big data ksii', -0.1442338526248932),
#  ('objective situation svs', -0.14538398385047913),
#  ('attack anomalybased methods', -0.14582112431526184),
#  ('applications comput sci', -0.14654719829559326),
#  ('membership function figure', -0.15001434087753296),
#  ('oneclass support machine', -0.15040329098701477),
#  ('attackers firewalls aim', -0.15061727166175842),
#  ('shaded parts inside', -0.152622252702713),
#  ('outlier score considering', -0.15298831462860107),
#  ('principal input data', -0.15485578775405884),
#  ('peoples livelihood science', -0.15579333901405334),
#  ('labeled data moreover', -0.15668898820877075),
#  ('fsvm algorithm based', -0.15707167983055115),
#  ('ids evaluation program', -0.1575518548488617),
#  ('improved software security', -0.16003316640853882),
#  ('hybridizes statistical techniques', -0.16052672266960144),
#  ('nearest neighbors considered', -0.1619148850440979),
#  ('shortest possible time', -0.16193759441375732),
#  ('hybrid feature selection', -0.16280320286750793),
#  ('created massive collections', -0.16510918736457825),
#  ('big data', -0.1651536524295807),
#  ('classification effect fsvm', -0.17499426007270813),
#  ('computer department beijing', -0.176079660654068),
#  ('japan email ytarutnokayamauacjp', -0.17635506391525269),
#  ('normal traces participate', -0.17669641971588135),
#  ('massive collections f', -0.1793462038040161),
#  ('vector machine table', -0.18105250597000122),
#  ('density estimate however', -0.18127980828285217),
#  ('r respectively represent', -0.1812865138053894),
#  ('traces contain lprcp', -0.18200615048408508),
#  ('discriminant eigenvectors subsequently', -0.184531569480896),
#  ('department beijing institute', -0.18548190593719482),
#  ('computer security applications', -0.18685591220855713),
#  ('machine learning ml', -0.18761253356933594),
#  ('corresponding author tel', -0.18764165043830872),
#  ('supervision lc project', -0.19451647996902466),
#  ('enough detailed experiments', -0.19841524958610535),
#  ('preprocessing step according', -0.20094919204711914),
#  ('ksii trans internet', -0.2010185420513153),
#  ('semisupervised support vector', -0.20282858610153198),
#  ('vector machine algorithm', -0.20283538103103638),
#  ('comprehensive detection performance', -0.20587122440338135),
#  ('need large numbers', -0.20866811275482178),
#  ('noise removal probabilistic', -0.20966044068336487),
#  ('exponential decay rule', -0.21076065301895142),
#  ('small data', -0.21645241975784302),
#  ('missing rate false', -0.21679291129112244),
#  ('online service unavailable', -0.21686342358589172),
#  ('objective function differently', -0.21803289651870728),
#  ('dimensional ata sets', -0.21807986497879028),
#  ('high accuracy bloom', -0.22058293223381042),
#  ('data streams ieee', -0.22738105058670044),
#  ('wan sd fuzzy', -0.22761717438697815),
#  ('prototype ωk computed', -0.22972139716148376),
#  ('model differ ent', -0.2304554581642151),
#  ('information technology growing', -0.23168373107910156),
#  ('third step different', -0.23259976506233215),
#  ('better classification performance', -0.23297768831253052),
#  ('real environment based', -0.23408284783363342),
#  ('introducing two different', -0.23450997471809387),
#  ('visvis assuring correct', -0.2375294268131256),
#  ('anomaly detection tasks', -0.23776403069496155),
#  ('open access article', -0.2383190393447876),
#  ('android malware classification', -0.23864805698394775),
#  ('popular neural network', -0.23996472358703613),
#  ('unit computed according', -0.24215558171272278),
#  ('intrusion detection eduardo', -0.24266475439071655),
#  ('example local density', -0.2428532838821411),
#  ('communications engineering department', -0.24470482766628265),
#  ('reallife data sets', -0.24677139520645142),
#  ('w intrusion prediction', -0.24735420942306519),
#  ('preprocess system call', -0.24882137775421143),
#  ('lowest missing rate', -0.24888251721858978),
#  ('density estimation similar', -0.2520103454589844),
#  ('design fuzzy membership', -0.2562946379184723),
#  ('generated network fig', -0.2567150294780731),
#  ('class ωk posterior', -0.2571742534637451),
#  ('method avoids imperfection', -0.26037371158599854),
#  ('zeng local kernel', -0.2605002820491791),
#  ('promising result index', -0.2620391845703125),
#  ('xnt g xi', -0.26217374205589294),
#  ('nids depends much', -0.2625811994075775),
#  ('raw data space', -0.26301610469818115),
#  ('sets feature reduction', -0.2633316218852997),
#  ('matching degree respectively', -0.2633671164512634),
#  ('guidelines traditional fuzzy', -0.26337459683418274),
#  ('ensemble system trained', -0.2634781002998352),
#  ('corresponding feature vector', -0.2701503038406372),
#  ('short sequence pattern', -0.2716031074523926),
#  ('radial basis kernel', -0.2724193036556244),
#  ('heterogeneous anomaly detectors', -0.27283790707588196),
#  ('respectively connectivitybased outlier', -0.27319350838661194),
#  ('projections thus selected', -0.2747466564178467),
#  ('calculated using kernel', -0.28227680921554565),
#  ('using eigenvectors eigenfaces', -0.28476831316947937),
#  ('anomalybased ids nevertheless', -0.28719598054885864),
#  ('number appl sci', -0.2876889109611511),
#  ('construct normal behavior', -0.28948545455932617),
#  ('detect attacks whose', -0.2899572253227234),
#  ('maps pca filtering', -0.29079923033714294),
#  ('traffic finally section', -0.2915417551994324),
#  ('detect abnormal behaviours', -0.29361674189567566),
#  ('nearest neighbors reverse', -0.2947283089160919),
#  ('interesting problems related', -0.29536715149879456),
#  ('sequence matching method', -0.29541903734207153),
#  ('call patterns ieee', -0.29561054706573486),
#  ('rare system calls', -0.2984243929386139),
#  ('anomalous namely anomalybased', -0.2990174889564514),
#  ('enough class separation', -0.30059894919395447),
#  ('quantity imbalance samples', -0.3020102083683014),
#  ('data svmbased algorithm', -0.30208820104599),
#  ('sample set located', -0.3032885789871216),
#  ('detect unknown types', -0.30536365509033203),
#  ('shortterm memory recurrent', -0.3059314489364624),
#  ('among five algorithms', -0.3073180615901947),
#  ('work principal component', -0.3126007616519928),
#  ('security abstract distributed', -0.3128039836883545),
#  ('grid search method', -0.3169426918029785),
#  ('feature selection ratio', -0.3177138566970825),
#  ('data appl sci', -0.3203519880771637),
#  ('good classification results', -0.32765060663223267),
#  ('data mining int', -0.32966306805610657),
#  ('local ensity differs', -0.33031466603279114),
#  ('minimum hypersphere center', -0.33046138286590576),
#  ('thus pca generates', -0.33281636238098145),
#  ('call sequence intrusion', -0.33321550488471985),
#  ('f hu g', -0.33374911546707153),
#  ('large dimensional problems', -0.334075927734375),
#  ('engineering department university', -0.3341660797595978),
#  ('input space modelling', -0.3342229127883911),
#  ('service ddos attack', -0.3347630202770233),
#  ('improved densitybased initial', -0.33574622869491577),
#  ('outlier factor lof', -0.33763551712036133),
#  ('negative hypersphere centers', -0.33765026926994324),
#  ('corresponding block diagram', -0.3383094072341919),
#  ('highest detection rate', -0.3390772342681885),
#  ('q hurst w', -0.339111328125),
#  ('function matrix therefore', -0.33961471915245056),
#  ('data description svdd', -0.33978986740112305),
#  ('machine inf sci', -0.340366393327713),
#  ('following four types', -0.34264710545539856),
#  ('potential attackers include', -0.3434241712093353),
#  ('gaussian component corresponds', -0.34349676966667175),
#  ('guarantee statistical validity', -0.3438038229942322),
#  ('based computers ksii', -0.34579983353614807),
#  ('good generalization ability', -0.349496066570282),
#  ('sets inf sci', -0.35102203488349915),
#  ('natural science foundation', -0.3522181212902069),
#  ('signatures may cause', -0.35370194911956787),
#  ('theory statistical learning', -0.3550446927547455),
#  ('previous work done', -0.3556402921676636),
#  ('vector set containing', -0.357013463973999),
#  ('existing fsvmbased algorithms', -0.3570992052555084),
#  ('ieee trans dependable', -0.35758334398269653),
#  ('windows pc different', -0.3579023480415344),
#  ('cloud computing beijing', -0.3612218499183655),
#  ('computer science hofstra', -0.3620133399963379),
#  ('initial cluster centers', -0.36824551224708557),
#  ('respectively gauss kernel', -0.3711705803871155),
#  ('complex appl sci', -0.37182971835136414),
#  ('distinguish abnormal points', -0.37221211194992065),
#  ...]

# %%
with open("../noisy_data_3gram.txt","x") as f:
    f.write(str(lst))

# %%
sns.set()
articles.data["creation_year"] = articles.data["creation_date"].apply(lambda x:  str(x)[:4])
article_data_df = articles.data.groupby(['creation_year', 'topic']).size().reset_index().pivot(columns='topic', index='creation_year', values=0)

article_data_df.plot(kind="bar",stacked=True,colormap="GnBu")

# %%
import calendar
from datetime import datetime

# %%
sns.set(rc={'figure.figsize':(35,30)})
grid = plt.GridSpec(2, 3, wspace=0.2, hspace=0.2)
plt.rc("xtick",labelsize=40)
plt.rc("ytick",labelsize=40)
fig, axs = plt.subplots(1,4)
publishers_seaborn = sns.countplot(list(map(lambda L: L[1], publishers)),palette="GnBu",ax=axs[0])
publishers_seaborn.set_xticklabels(publishers_seaborn.get_xticklabels(),rotation=90,weight='bold')
publishers_seaborn.set_title("Number of articles per publisher",weight='bold').set_fontsize(25)
publishers_seaborn.set_ylabel("Count",weight="bold").set_fontsize(25)
publishers_seaborn.set_xlabel("Publisher",weight='bold').set_fontsize(25)
month_date_seaborn = sns.countplot(sorted(articles.data["creation_date"].apply(lambda x:  calendar.month_name[int(str(x)[5:7])]),key=lambda day: datetime.strptime(day, "%B")),palette="GnBu",ax=axs[1]) # by month
month_date_seaborn.set_xticklabels(month_date_seaborn.get_xticklabels(), rotation=90,weight='bold')
month_date_seaborn.set_title("Number of articles per month",weight='bold').set_fontsize(25)
month_date_seaborn.set_ylabel("Count",weight="bold").set_fontsize(25)
month_date_seaborn.set_xlabel("Month",weight='bold').set_fontsize(25)

year_date_seaborn = sns.countplot(sorted(list(articles.data["creation_date"].apply(lambda x:  str(x)[:4]))),palette="GnBu",ax=axs[2])
year_date_seaborn.set_xticklabels(year_date_seaborn.get_xticklabels(), rotation=90,weight='bold')
year_date_seaborn.set_title("Number of articles per year",weight='bold').set_fontsize(25)
year_date_seaborn.set_ylabel("Count",weight="bold").set_fontsize(25)
year_date_seaborn.set_xlabel("Year",weight='bold').set_fontsize(25)
taxonomy_seaborn = sns.barplot(x="taxonomy_category",y="number_of_articles",data=df_counts,palette="GnBu",ax=axs[3])
taxonomy_seaborn.set_xticklabels(taxonomy_seaborn.get_xticklabels(), rotation=90,weight='bold')
taxonomy_seaborn.set_title("Number of articles per taxonomy category",weight='bold').set_fontsize(25)
taxonomy_seaborn.set_ylabel("Count",weight="bold").set_fontsize(25)
taxonomy_seaborn.set_xlabel("Category",weight="bold").set_fontsize(25)

sns.set()
articles.data["creation_year"] = articles.data["creation_date"].apply(lambda x:  str(x)[:4])
article_data_df = articles.data.groupby(['creation_year', 'topic']).size().reset_index().pivot(columns='topic', index='creation_year', values=0)
plt.subplots_adjust(hspace = 1.2)
fig.subplots_adjust(bottom=0.65)
fig.savefig("pubs_taxonomy_dates.png")

# %%
fig, ax = plt.subplots(figsize=(30,20))
stacked_bar_seaborn = article_data_df.plot(ax=ax,kind="bar",stacked=True,colormap="GnBu")
stacked_bar_seaborn.set_xticklabels(stacked_bar_seaborn.get_xticklabels(), rotation=90)
plt.rc("xtick",labelsize=40)
plt.rc("ytick",labelsize=40)
plt.legend(fontsize=40)
stacked_bar_seaborn.set_title("Yearly Articles by Topic",weight='bold').set_fontsize(40)
stacked_bar_seaborn.set_ylabel("Count",weight="bold").set_fontsize(40)
stacked_bar_seaborn.set_xlabel("Year",weight="bold").set_fontsize(40)
stacked_bar_seaborn.figure.savefig("yearly_topic.png")

# %%
sns.countplot(sorted(list(articles.data["creation_date"].apply(lambda x:  str(x)[:4]))),palette="GnBu") # by year

# %%
counts = {}
for key in categories:
    l = 0
    for lst in categories[key].values():
        l += len(lst)
    counts[key] = l
print(counts)
df_counts = pd.DataFrame({"taxonomy_category":list(counts.keys()),"number_of_articles":list(counts.values())})
# Out:
# {'Lack of Real-World Network Data': 15, 'Noisy Data': 6, 'Redundant Data': 32, 'Weakly Correlated Data': 1, 'Too Few Labeled Data': 16, 'Imbalanced Data': 18, 'Big Data': 34, 'Dynamic Data': 17, 'Small Data': 20}

# %%
df_counts
# Out:
#                  taxonomy_category  number_of_articles
# 0  Lack of Real-World Network Data                  15
# 1                       Noisy Data                   6
# 2                   Redundant Data                  32
# 3           Weakly Correlated Data                   1
# 4             Too Few Labeled Data                  16
# 5                  Imbalanced Data                  18
# 6                         Big Data                  34
# 7                     Dynamic Data                  17
# 8                       Small Data                  20

# %%
sns.barplot(x="taxonomy_category",y="number_of_articles",data=df_counts,palette="GnBu")
plt.xticks(rotation=90)
plt.title("Number of articles per taxonomy category")
# Out:
# Text(0.5, 1.0, 'Number of articles per taxonomy category')
